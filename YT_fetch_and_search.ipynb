# %% [markdown]
# <a href="https://colab.research.google.com/github/aithentic-dev/colab-yt/blob/main/YT_fetch_and_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YouTube Comments Summarization with OpenAI
#
# In this notebook we harness the power of AI to deeply analyze YouTube comments and video transcripts.
#
# 1. Fetch Video Transcripts: Automatically retrieve the textual content of YouTube videos using the youtube-transcript-api.
# 2. Extract and Analyze Comments: Use the YouTube Data API to gather viewer comments from specified videos for further analysis.
# 3. Summarize and Link Comments to Transcripts: Apply OpenAI's GPT-3 model to summarize comments and correlate them with video transcripts, extracting meaningful insights that highlight viewer engagement and feedback.
# 4. Perform Sentiment Analysis: Utilize Hugging Face’s sentiment-analysis model to classify comments into positive, negative, or neutral categories, providing a quantitative measure of audience sentiment.
# 5. Visualize Data: Display sentiment analysis results using pie charts to give a visual representation of audience reactions.

# %% [markdown]
# ## Setup
# First, let's import necessary libraries and define our API keys and youtube video id.
#
# Save the following three tokens in the secrets to be able to run this notebook:
#
# 1.   YT_APIKEY - Google API Key
# 2.   OPENAI_API_KEY - OpenAI API Key

# %%
# !pip install openai

from openai import OpenAI
from google.colab import userdata

# Instantiate OpenAI client (ensure your OpenAI API key is set in your environment variables or pass directly here).
client = OpenAI(
    api_key=userdata.get('OPENAI_API_KEY')
)

VIDEOID = 'boHg6quSZtI'#'boHg6quSZtI'
VIDEO_ID = 'boHg6quSZtI' #'1Vn_9iQfKek'
GOOGLE_APIKEY = userdata.get('YT_APIKEY')
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
YT_TRANSCRIPTS = '/content/drive/My Drive/YouTubeTranscripts'
AZ_STR = userdata.get('AZ_STR')
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.57.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)

# %% [markdown]
# ## Fetching Youtube Video Transcription

# %%
# Install required packages
# !pip install youtube-transcript-api tiktoken openai
VIDEO_ID = '1Vn_9iQfKek'
# Import required libraries
from youtube_transcript_api import YouTubeTranscriptApi
import tiktoken
from typing import List
import time

def get_video_transcript(video_id: str) -> str:
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['te', 'en'])
        full_transcript = " ".join(entry['text'] for entry in transcript)

        # Print the full transcript
        print("=== FULL TRANSCRIPT ===")
        print(full_transcript)
        print("\nTranscript length (characters):", len(full_transcript))
        print("===== END TRANSCRIPT =====\n")

        return full_transcript
    except Exception as e:
        print(f"Failed to fetch transcript: {e}")
        return ""


def chunk_text(text: str, max_tokens: int = 12000) -> List[str]:
    """Split text into chunks that fit within token limit."""
    try:
        # Initialize tokenizer for GPT-3.5-turbo
        enc = tiktoken.encoding_for_model("gpt-3.5-turbo")

        words = text.split()
        chunks = []
        current_chunk = []
        current_length = 0

        for word in words:
            word_tokens = len(enc.encode(word + " "))
            if current_length + word_tokens > max_tokens:
                # Save current chunk and start new one
                chunks.append(" ".join(current_chunk))
                current_chunk = [word]
                current_length = word_tokens
            else:
                current_chunk.append(word)
                current_length += word_tokens

        # Add the last chunk if it exists
        if current_chunk:
            chunks.append(" ".join(current_chunk))

        return chunks
    except Exception as e:
        print(f"Error in chunk_text: {e}")
        # Fallback to a simpler chunking method if tiktoken fails
        words = text.split()
        chunk_size = 3000  # Approximate size that should stay under token limit
        return [" ".join(words[i:i + chunk_size]) for i in range(0, len(words), chunk_size)]

def get_transcript_summary(transcript: str, client) -> str:
    # Split transcript into smaller chunks
    chunks = chunk_text(transcript)
    summaries = []

    # Process each chunk
    for i, chunk in enumerate(chunks):
        try:
            response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": f"You are summarizing part {i+1} of {len(chunks)} of a YouTube video transcript. Provide a concise summary of this section."},
                    {"role": "user", "content": chunk}
                ]
            )
            summaries.append(response.choices[0].message.content)
            # Add a small delay to avoid rate limiting
            time.sleep(1)
        except Exception as e:
            print(f"Error processing chunk {i+1}: {e}")

    # Combine chunk summaries into final summary
    if summaries:
        final_prompt = "Combine these section summaries into a coherent overall summary:\n\n" + "\n\n".join(summaries)
        try:
            final_response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "Create a coherent overall summary from these section summaries."},
                    {"role": "user", "content": final_prompt}
                ]
            )
            return final_response.choices[0].message.content
        except Exception as e:
            print(f"Error creating final summary: {e}")
            return "\n\n".join(summaries)  # Return individual summaries if final combination fails

    return "Failed to generate summary."

# Usage example:

#from openai import OpenAI
#client = OpenAI(api_key='OPENAI_API_KEY')  # Replace with your actual API key

#video_id = 'VIDEO_ID'  # Replace with your YouTube video ID
video_transcript = get_video_transcript(VIDEOID)
transcript_summary = get_transcript_summary(video_transcript, client)
print(transcript_summary)
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.3-py3-none-any.whl.metadata (17 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.57.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.2.3)
# Downloading youtube_transcript_api-0.6.3-py3-none-any.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 8.8 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.8 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api, tiktoken
# Successfully installed tiktoken-0.8.0 youtube-transcript-api-0.6.3
# === FULL TRANSCRIPT ===
# హలో వెల్కమ్ టు అవర్ ఛానల్ మొత్తానికి అల్లు అర్జున్ గారు రిలీజ్ అయ్యారు ఇంటికి వచ్చారు ఒక రోజంతా జైల్లో ఉండాల్సిన తప్పైతే అల్లు అర్జున్ గారు చేయలేదు అన్నది నా వ్యక్తిగత అభిప్రాయం బట్ అగైన్ ఎందుకు జరిగింది ఏంటి అన్నది ఇంకా వారి విజ్ఞతకే వదిలేద్దాం మనం దాన్ని పట్టించుకోవాల్సిన అవసరం లేదు ఎంత విచిత్రంగా ఉందంటే అండి పరిస్థితి తెలంగాణలో డికే అరుణ గారు గాని లేకపోతే బండి సంజయ్ గారు గాని ప్రతి ఒక్క బిజెపి నాయకుడు అలాగే బిఆర్ఎస్ వాళ్ళు కూడా అల్లు అర్జున్ అరెస్ట్ ని తీవ్రంగా ఖండించారు కానీ ఆంధ్రాకు వచ్చే లోపు బిజెపి తరపున ఉన్న వాళ్ళు అంటే పురందేశ్వరి గాని లేకపోతే కూటంలో ఉన్న పవన్ కళ్యాణ్ గాని చంద్రబాబు గాని ఒక్క మాట కూడా మాట్లాడట్లేదు తెలంగాణలో ఉన్నది ఎవరు కాంగ్రెస్ కానీ కాంగ్రెస్ కి ఆపోజిట్ గా కూడా ఒక మాట కూడా మాట్లాడట్లేదు ఆంధ్రా నుంచి నాయకులు గాని కూటమి వాళ్ళు గాని మరి తెలంగాణలో బిజెపి వాళ్ళు మాట్లాడినప్పుడు ఆంధ్ర బిజెపి వాళ్ళు ఎందుకు మాట్లాడకూడదు పైగా సొంత బంధువు మొన్న థాంక్యూ పవన్ బాబాయ్ అని కూడా అన్నాడు ఎవరు అల్లు అర్జున్ పవన్ కళ్యాణ్ ఇంతవరకు దాని గురించి ప్రస్తావన లేదు అదే ఇంతకుముందు చంద్రబాబు నాయుడు అరెస్ట్ అయితే ఆగమేఘాల మీద వెళ్లి రోడ్డు మీద పడుకొని దొర్లాడి పొర్లు దండాలు పెట్టి అది చేసి ఇది చేసి అడిగి నానా యాగీ చేశాడు కానీ ఇప్పుడు పిన్ డ్రాప్ సైలెన్స్ అసలు ఏం మాటలు లేవు ఇంకా ఎందుకు ఏంటి అనేది వాళ్ళ విజ్ఞతకే వదిలేద్దాం ఇక్కడ ఈ వీడియో నేను చేసేదండి కొన్ని ఆసక్తి వ్యాఖ్యలు చేశారు రేవంత్ రెడ్డి గారు మన తెలంగాణ ముఖ్యమంత్రి రేవంత్ రెడ్డి గారు అవి దుమారమే రేపుతున్నాయి కానీ ఎక్కడ దుమారం రేగుతుంది అన్నది ఇక్కడ చర్చనీయ అంశం నిన్న రేవంత్ రెడ్డి గారు ఆ ఒక ఇండియా టుడే కాన్క్లేవ్ లో అనుకుంటా కాన్క్లేవ్వా ఎన్క్లేవ్ ఐ డోంట్ నో వాట్ ఎవర్ ద ప్రోగ్రాం నేమ్ బట్ ఐ థింక్ ఇట్స్ ఇండియా టుడే ఒక చర్చ వేదికలో మాట్లాడుతూ సినిమా యాక్టర్లు ఏమైనా సరిహద్దుల్లోకి వెళ్లి వాళ్ళు పోరాటాలు చేశారా వాళ్ళు ఏమైనా యుద్ధాలు చేసి దేశాన్ని కాపాడారా ఎందుకు వాళ్లకు అంత ఇంపార్టెన్స్ ఇవ్వాలి ఆ బాధిత కుటుంబాన్ని ఒకసారి మీరు ఊహించుకోండి వారి తరపున మీరు ఒక్కసారి ఆలోచించండి ఆ తల్లిని కోల్పోయాడు ఒక బిడ్డ ఇప్పటికి ఇంకా కోమాలోనే ఉన్నాడు అంటే ఇక్కడ రేవంత్ రెడ్డి గారి మాటలతో కొంతవరకు నేను ఏకీభవిస్తున్నాను చట్టాలు అన్నవి ఎవరికైనా ఒకేలాగా ఉండాలి ఇక్కడ చట్టాలు వీరి కోసం ఒకలాగా ఇంకొకరి కోసం ఒకలాగా ఉండాలని నేను ఎప్పుడూ అసలు అనను అండ్ ఆల్సో సినిమాలు అన్నవి నా వ్యక్తిగత అభిప్రాయం చాలా సార్లు మీకు చెప్పాను సినిమాలు అన్నవి కేవలం ఎంటర్టైన్మెంట్ అండి సినిమాల నుంచి మనం నేర్చుకునేది సినిమాలు చూసి మన జీవితాన్ని మనం మార్చుకునేది ఏమీ ఉండదు మూడు గంటలు చూసామా ఆ చూసినప్పుడు హ్యాపీగా ఫీల్ అవుతాం ఆ సినిమా సూపర్ హిట్ అయితే ఒక నాలుగు ఐదు రోజులు ఎక్కువ మాట్లాడుకుంటాం తర్వాత ఐ విల్ బి బిజీ ఇన్ అవర్ లైఫ్ ఇప్పుడు పుష్ప చూసి నేను ఏం నేర్చుకుంటా అంటే నేర్చుకునేది లేదు ఏం లేదు ఆర్ఆర్ ఆర్ చూసి ఏం నేర్చుకుంటాం అంటే ఏం లేదు ఎవరి సినిమా అయినా గాని జస్ట్ ఫర్ ఎంటర్టైన్మెంట్ నేను చక్కటి ఉదాహరణ కూడా ఇంతకు ముందు చెప్పాను మహర్షి సినిమా చూసి వీకెండ్ ఫార్మింగ్ అని కొంతమంది బయలుదేరారు ఏది ఒక రెండు మూడు వారాల వరకు ఆ సినిమా ఉన్నంతవరకు తర్వాత వీకెండ్ ఫార్మింగ్ లేదు ఏం లేదు సీ ఎవరీ వన్ విల్ బి బిజీ ఇన్ లైఫ్ లైక్ యు నో మనకు కాలక్షేపం కోసం ఎస్ మూవీ ఇస్ పార్ట్ ఆఫ్ అవర్ లైఫ్ బికాజ్ అదొక పెద్ద ఎంటర్టైన్మెంట్ మనకు ఇండియాలో అండ్ ఎవరీ వన్ లైక్స్ టు వాచ్ ఏ మూవీ ఓవర్ ది వీకెండ్ ఆర్ యు నో విత్ ఫ్యామిలీ మెంబర్స్ అంతకంటే వాటికి నేను ఎక్కువ ఇంపార్టెన్స్ కూడా ఇవ్వను కానీ ఇక్కడ రేవంత్ రెడ్డి గారు సరిహద్దుల్లో పోరాడారా అంటే అది కొంచెం హార్ష్ అని నాకు అనిపిస్తుంది వస్తుంది ఎందుకంటే ఇప్పుడు ఒక సినిమాకు 10 కోట్లు కలెక్ట్ అవుతే మూడు కోట్లు జిఎస్టి కడుతున్నారు ఎవరి సినిమా వాళ్ళు గవర్నమెంట్ లకి ఆదాయం వస్తుంది ఆ వచ్చిన డబ్బుని వాళ్ళు ప్రజలకు మంచి పనుల కోసం కూడా ఉపయోగించొచ్చు సో మరీ సినిమాని తీసి పక్కన పడేయాల్సిన అవసరం అయితే లేదు బట్ సినిమా అన్నది ప్యూర్లీ ఎంటర్టైన్మెంట్ దాని వల్ల నేర్చుకొని మనం బాగుపడేది ఏమి ఉండదు కానీ ఒకటే నేను ఎప్పుడూ కూడా ఆలోచించేది ఏందంటే సినిమాల్ని సినిమా లాగే చూడాలి ఇప్పుడు మన ప్రత్యర్థుల సినిమా అయితే మనం దాన్ని తీసి పడేయాలి అని నేను ఎప్పుడూ అనుకోను ఎందుకంటే ఒకటి ఎంప్లాయ్మెంట్ క్రియేట్ చేస్తుంది సినిమా ఇండస్ట్రీ అనేది వేల కోట్ల టర్న్ ఓవర్ ఉంది ఎంప్లాయ్మెంట్ క్రియేట్ చేస్తుంది అండ్ 10 మందికి ఉపాధి కల్పిస్తుంది అండ్ ఆల్సో గవర్నమెంట్ కి టాక్స్ కడుతుంది ఆ దృష్టిలో చూస్తే సినిమాని తక్కువ చేసి చూడాల్సిన అవసరం లేదు ఇట్స్ లైక్ ఎనీ అదర్ ప్ర ...
#
# Transcript length (characters): 11644
# ===== END TRANSCRIPT =====
#
# The video transcript addresses a range of topics related to movie actors and political figures, primarily focusing on individuals such as Allu Arjun, Sanjay Dutt, Pawan Kalyan, Chandrababu Naidu, and their interactions and influence in society. The speaker also talks about the responsibilities of actors like Chiranjeevi, Mahesh Babu, and Prabhas, emphasizing the significance of the film industry and the obligations of influential individuals within it. Additionally, the discussion delves into the political landscape in Andhra Pradesh, highlighting instances of actions taken against individuals by politicians like Pawan Kalyan and Revanth Reddy, as well as the strategies employed by different parties in Telangana and the inherent uncertainties in political environments.

# %% [markdown]
# ## Fetching YouTube Video Comments

# %%
from googleapiclient.discovery import build

# Function to get YouTube comments
def get_comments(video_id, api_key):
    youtube = build('youtube', 'v3', developerKey=api_key)
    comments = []
    response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100
    ).execute()

    while response:
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)

        if 'nextPageToken' in response:
            response = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                pageToken=response['nextPageToken'],
                maxResults=100
            ).execute()
        else:
            break

    return comments

video_comments = get_comments(VIDEOID, GOOGLE_APIKEY)
print(video_comments)
# Out:
# ['Mega ఫ్యామిలీ మీద పడి ఏడిచే బదులు... మీ 11 రెడ్డి నీ, షా రెడ్డిని, bha రెడ్డిని కలపచ్చు kadha.... Bro', 'Aapu swamy nuvu', 'Mundu ni badento cheppu😂😂😂   Vado actru iido vintha ycp midea bokars ki 😂😂😂😂😂😂adi yela chintha 😂😂😂😂😂😂😂😂😂', 'బీజేపీ evm game బాగా ఆడినా... కాంగ్రెస్ మీద క్లారిటీ బాగా వుంది👌 కానివ్వండి దూసుకెళ్ళండి 👍', 'Ammanannapotheadavanivalluysrchanipothegundeaagipoendatavandalamandikiedikuudasilliekadarajakieyanayakulubathukutheruvuvalladipriedamfaitaraysr', 'Nee bathkuku villani ane sthayara nidhi thoooo', '🤭🤭🪑🪑🌺🌺👔👔', 'Excellent 🎉', 'Nuvu kukkalga moruguthunav kadara morugu', 'Nuventha yetakaram chesina mega familyni matladentha right beku ledu lera', 'Orey  doctor neku minimum commensence unda  chiranjeevi garu dhandam pettuna videos ela bayatiki vavhindira', 'Cinima vallake revanthreddy correct 😮', 'Bunny ganni uri teeyali, society nundi bahishkarinchali', 'Ayanemi dandam petta ni cheppaledu okastayilo vnnavaallu. Parasparam dandaalu pettukuntaaru', 'RR gadu poor mind set and PK gadu mental fellow...', 'meeru kooda alochinchandi revathi gurinchi', 'Revathi gurinchi enduku maatladau', 'Urge CM of Telangana not to yield to pressures of cene industry ,to increase ticket rstes ,in the first week of release.\nWhy dont the celebrity Stars reduce their remuneration. \nState or Central govt must impose a cieling on remuneration of film stars ,and staff.,to help contain inflation. \nWhy do they require imported cars ,Benz,RollsRoyce.', 'In general, it is good step ,to put cene industry in their proper place.\nTelugu cene indutry is controlled by Kamma community of AP.\nRevanth must help AP tobdrive away ceneindustry from Hyderabad ,including Ramoji .(RFC)', 'నువ్వు చలించు ఐతే', 'Jagan pulikadhara', 'Jagan ki cm ela avvali help chey icon reddy', 'Telangana matter adhi icon  reddy.', 'Us lo undi, sodhi vadhura', 'Nee badha endhira  us reddy', 'Well said brother !!', 'Enduku matladili ra vedava', 'money donation thisukune appudu matram devudu antaru 😂😂😂😂😂  movies nunchi 28%  tax thiskunnappudu sankalu gudhukuntu thiskuntaru ee revanth', 'Orey nayana nuvv enduku vedios chestunao neku aena artham avtha unnaya thu neee yamma bathukulo  na modda', 'Telugu states  lo chala chala Chetha politics nadusthunayee.\nPeddalu, medhavulu deeni gurunichi alochinchali.', 'History books lo tuglak undevadu ani vinnam memu..dec 3 2023 nundi chustunam devudu unnada ma Telangana shani daridram epud potado...ma karma ra babu...telugu CM history ilanti bekar CM evaru leru raru', "YCP party'..,...... సినిమా వాళ్ల గురించి చాలా ఆలోచించి tiket 10RS చేశారు..........రేవంత్ 800 పర్మిషన్ ఇచ్చాడు.......అల్లు అర్జున్ కే అడగాలి.....10 బెటర్ హా 800 బెటర్ హా..........అడుగు కుక్కల డాక్టర్ 😂", 'Yes u correct cepinaru na', 'రేవంత్ రెడ్డి జోలికి వెళ్తే ఈ సినిమా వాళ్ళు హైదరాబాదులో సినిమాలు తీసుకోలేరు వీళ్ళందర్నీ ముడ్డి మీద తన్ని ఆంధ్ర కి పంపిస్తాడు జగన్ ఏమీ అనడు అని ఆయన మీద పడి ఏడుస్తారు వీరందరూ', 'Yes, CM Revanth Reddy Gaaru Correct ga chepparu', 'ఇలా అరెస్ట్ చేస్తే చిరంజీవి ఎన్ని సినిమాలు లలో ఉరిసిక్ష  వెయ్యాలి', 'Aadoka gumpu mestri.. Local Body Elections Pettani Cheptham Vaani Sangathi.. Potti Saaley Gaadu.. Aassllu Taggedhey Ley', '🔴 దేశ కాపు కులస్థుల నాయకుడు మా పవన్ కళ్యాణ్ ఆంధ్ర ప్రదేశ్ కు కాబోయే ముఖ్యమంత్రి 🔴', 'Good MSG 🎉', 'వీళ్లంతా దొంగల ముఠా ప్రదీప్', 'enka ni kulluu poleda', 'Baga chepparu ee vedio lo.....chala correct vishayalu.', 'I really love the PK photo in green shirt that you use in your vedios🙂', 'Very very true..... Cbn pk vachinappatinunchi ilaney ayindi.  Especially pk and his sh@meless fans. Youth ni tappu daari pattistunnadu PK and CBN. Daridrapu kotti santha.', '8:5 💯 true. Yes pavan kalyan and CBN are d@ngerous for the society.  It is actually in my heart.   You said today. Ee moment loney mi channel ni subscribe chesa nenu eroju.', 'బాబు రాష్ట్రాన్ని ప్రజలనుభ్రస్టుపట్టిస్తున్నారు.😢😢😢😢😢😢😢😢😢😢😢😢', 'బెనిఫిట్ షో లకి అనుమతి ఇచ్చిన వాళ్ళని కూడా లోపలవేయ్యాలికదా???', 'Vaadu .( Pavala gaadu)....snake gaadiki posting (Nagababu - The minister) icch ...

# %% [markdown]
# ## Summarizing Comments
# Summarize comments using OpenAI's GPT model.

# %%
# Function to split comments into manageable batches
def batch_comments(comments, max_tokens=2048):
    batches = []
    current_batch = []
    current_length = 0

    for comment in comments:
        comment_length = len(comment.split())
        if current_length + comment_length > max_tokens:
            batches.append(current_batch)
            current_batch = [comment]
            current_length = comment_length
        else:
            current_batch.append(comment)
            current_length += comment_length

    if current_batch:
        batches.append(current_batch)

    return batches

# Function to get summaries from OpenAI
def get_comments_summaries(batches):
    summaries = []

    for batch in batches:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "Summarize the following comments while keeping the detailed context."},
                {"role": "user", "content": " ".join(batch)}
            ]
        )
        print(response)
        summaries.append(response.choices[0].message.content)

    return summaries

# Function to create final summary from summaries
def create_final_summary(summaries, transcript_summary):
    summary_text = " ".join(summaries)
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
              {"role": "system", "content": f"This is the summary of a YouTube video's transcript: {transcript_summary}. A user has commented on the video. Your task is to analyze this comment in the context of the video transcript. Based on the comment content and its relation to the transcript, please provide detailed insights, addressing these key points:\n1. Identify positive aspects of the video that the comment highlights and link these to specific parts of the transcript where possible.\n2. Identify any criticisms or areas for improvement mentioned in the comment, and relate these to relevant sections of the transcript.\n3. Based on the feedback or suggestions in the comment, recommend new content ideas or topics for future videos that align with the viewer's interests and the overall content strategy but don't make up things from your side unnecessarily. Ensure your analysis is clear and includes specific examples from both the comment and the transcript to support your insights."},
              {"role": "user", "content": summary_text}
        ]
    )
    return response.choices[0].message.content

# %%
batches = batch_comments(video_comments)
summaries = get_comments_summaries(batches)
final_comments_summary = create_final_summary(summaries, transcript_summary)
print(final_comments_summary)
# Out:
# ChatCompletion(id='chatcmpl-Alje5eG8J0ogklXwnGM514YPjyXof', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Revanth Reddy criticizes film stars for their influence in the mega family, mentioning about their indifference and the need for clarity from Congress. Many comments express support for his statements and criticize the behavior of certain political figures. There is also a call to increase movie ticket rates, cap celebrities' remunerations, and a suggestion to put the cinema industry in its place. Some users show dissatisfaction with the behavior of certain celebrities and political figures in the Telugu states, emphasizing the need for ethical conduct in politics and entertainment industry.", refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1735940241, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=107, prompt_tokens=8656, total_tokens=8763, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-Alje7ZUZZjKpE9v6GN7MMH8F4Epdd', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The comments discuss various political figures and actors in the Telugu industry. Some criticize specific individuals like Chiranjeevi and Pawan Kalyan, expressing disappointment in their actions. Others mention political developments, including the involvement of Revanth Reddy and analysis of parties like YSRCP and TDP. The comments also raise concerns about governance and corruption, as well as the role of cinema personalities in politics, particularly focusing on Jagan and Allu Arjun. Additionally, there are remarks about the importance of communicating political achievements effectively and the need to learn from past mistakes.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1735940243, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=117, prompt_tokens=9396, total_tokens=9513, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-Alje8FEENp2FUna9upZQgNQIPFKh9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comments discuss the dynamics between various political figures in Andhra Pradesh, including references to Chandrababu Naidu, Pawan Kalyan, Jagan Mohan Reddy, and Revanth Reddy. They mention instances of warnings given to leaders like Pawan Kalyan and Revanth Reddy by KCR, the reluctance of Pawan Kalyan to speak in Telangana, and allegations of opportunistic politics and unethical behavior. Additionally, there are comments praising certain political figures and criticizing others, highlighting power struggles and ongoing controversies in the political landscape. The remarks express opinions on various leaders' actions and decisions, often made in a critical or humorous tone.", refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1735940244, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=137, prompt_tokens=7409, total_tokens=7546, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# 1. **Positive Aspects Highlighted in the Comment:**
#    - The comment praises Revanth Reddy for criticizing film stars for their influence in the mega family, indicating support for those challenging the status quo within the film industry and politics.
#    - This sentiment aligns with the video transcript where discussions about political figures like Chiranjeevi, Pawan Kalyan, and their interactions and influences in society are highlighted. Revanth Reddy's call for clarity from Congress regarding celebrities also resonates with the need for ethical conduct in politics and the entertainment industry, which is a positive aspect highlighted in the comment.
#
# 2. **Criticisms and Areas for Improvement:**
#    - Criticisms in the comment include dissatisfaction with certain celebrities and political figures in the Telugu states, mentioning disappointments in the actions of individuals like Chiranjeevi and Pawan Kalyan. This aligns with the sections in the transcript where discussions about individuals' behaviors, responsibilities of actors, and criticisms of political figures are addressed.
#    - The call to increase movie ticket rates, cap celebrities' remunerations, and suggestions to rein in the cinema industry suggest a desire for more regulation and transparency within the entertainment sector, pointing towards potential areas of improvement in the industry.
#
# 3. **Recommendations for Future Video Content:**
#    - Given the viewer interest in ethical conduct in politics and entertainment, future videos could explore in-depth analyses of specific instances of unethical behavior or controversies involving film stars and political figures in the Telugu industry.
#    - Addressing governance, corruption, and effective communication of political achievements could be themes for future videos to educate viewers on these important aspects of the political landscape.
#    - Topics like power struggles, ongoing controversies, and the dynamics between various political figures in Andhra Pradesh, as highlighted in the comments, could be further explored to provide viewers with a deeper understanding of the political environment in the region.

# %% [markdown]
# ## Sentiment analysis of comments

# %%
def get_sentiments(comments):
    sentiment_counts = {'positive': 0, 'negative': 0, 'neutral': 0}

    for comment in comments:
        # Perform sentiment analysis on each comment individually
        try:
            sentiments = sentiment_analyzer(comment)
            # Assuming the first result is the relevant one if multiple are returned
            sentiment = sentiments[0] if isinstance(sentiments, list) and sentiments else None
        except Exception as e:
            print(f"Error in sentiment analysis: {e}")
            sentiment = None

        # Tally sentiments based on the analysis result
        if sentiment and sentiment['label'] == 'POSITIVE' and sentiment['score'] > 0.9:
            sentiment_counts['positive'] += 1
        elif sentiment and sentiment['label'] == 'NEGATIVE' and sentiment['score'] > 0.9:
            sentiment_counts['negative'] += 1
        else:
            sentiment_counts['neutral'] += 1

    return sentiment_counts

# %%
# Function to plot the sentiment distribution
def plot_sentiment_distribution(sentiment_counts):
    labels = sentiment_counts.keys()
    sizes = sentiment_counts.values()
    colors = ['gold', 'lightcoral', 'lightskyblue']
    explode = (0.1, 0, 0)  # explode 1st slice

    plt.pie(sizes, explode=explode, labels=labels, colors=colors,
            autopct='%1.1f%%', shadow=True, startangle=140)

    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
# !pip install transformers matplotlib

import matplotlib.pyplot as plt
from transformers import pipeline

# Initialize the sentiment-analysis pipeline
sentiment_analyzer = pipeline("sentiment-analysis")

sentiment_counts = get_sentiments(video_comments)
plot_sentiment_distribution(sentiment_counts)
# Out:
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 324, in run
#     session = self.get_default_session(options)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/index_command.py", line 71, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/index_command.py", line 100, in _build_session
#     session = PipSession(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/network/session.py", line 344, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/network/session.py", line 177, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/__init__.py", line 76, in get_default_environment
#     return select_backend().Environment.default()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/__init__.py", line 64, in select_backend
#     from . import pkg_resources
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/pkg_resources.py", line 16, in <module>
#     from pip._vendor import pkg_resources
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3292, in <module>
#     def _initialize_master_working_set():
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3266, in _call_aside
#     f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3317, in _initialize_master_working_set
#     tuple(dist.activate(replace=False) for dist in working_set)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3317, in <genexpr>
#     tuple(dist.activate(replace=False) for dist in working_set)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2829, in activate
#     fixup_namespace_packages(self.location)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2344, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2234, in _handle_ns
#     spec = importer.find_spec(packageName)
#   File "<frozen importlib._bootstrap_external>", line 1568, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 168, in _path_isdir
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 216, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1465, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1624, in _log
#     self.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 968, in handle
#     self.emit(record)
#   File "/usr/lib/python3.10/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1218, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/logging.py", line 112, in format
#     formatted = super().format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 686, in format
#     record.exc_text = self.formatException(record.exc_info)
#   File "/usr/lib/python3.10/logging/__init__.py", line 636, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.10/traceback.py", line 119, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#   File "/usr/lib/python3.10/traceback.py", line 502, in __init__
#     self.stack = StackSummary.extract(
#   File "/usr/lib/python3.10/traceback.py", line 383, in extract
#     f.line
#   File "/usr/lib/python3.10/traceback.py", line 306, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#   File "/usr/lib/python3.10/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/usr/lib/python3.10/tokenize.py", line 396, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/usr/lib/python3.10/tokenize.py", line 365, in detect_encoding
#     first = read_or_stop()
#   File "/usr/lib/python3.10/tokenize.py", line 323, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ^C
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-e9c1887476dd> in <cell line: 9>()
#       7 sentiment_analyzer = pipeline("sentiment-analysis")
#       8
# ----> 9 sentiment_counts = get_sentiments(video_comments)
#      10 plot_sentiment_distribution(sentiment_counts)
#
# NameError: name 'video_comments' is not defined

# %% [markdown]
# Fetch Transcripts

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import TextFormatter

def get_video_transcript(video_id):
    try:
        # First try to get available transcripts
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to get manually created transcripts first
        try:
            transcript = transcript_list.find_manually_created_transcript()
        except:
            # If no manual transcript, get the auto-generated one
            try:
                transcript = transcript_list.find_generated_transcript()
            except:
                # If no generated transcript in original language, get any available transcript
                transcript = transcript_list.find_transcript(['en', 'hi', 'te'])

        # Get the actual transcript
        transcript_data = transcript.fetch()

        # Format the transcript
        formatter = TextFormatter()
        formatted_transcript = formatter.format_transcript(transcript_data)

        return formatted_transcript

    except Exception as e:
        print(f"Failed to fetch transcript: {str(e)}")
        # Print available languages for debugging
        try:
            available_transcripts = YouTubeTranscriptApi.list_transcripts(video_id)
            print("Available transcript languages:")
            for transcript in available_transcripts:
                print(f"- {transcript.language_code}")
        except:
            print("Could not retrieve available transcripts")
        return ""

def get_transcript_summary(transcript):
    if not transcript:
        return "No transcript available to summarize."

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Provide a detailed summary of the given youtube video transcript."},
            {"role": "user", "content": transcript}
        ]
    )
    return response.choices[0].message.content

# Usage
video_id = "YOUR_VIDEO_ID"
video_transcript = get_video_transcript(video_id)
if video_transcript:
    transcript_summary = get_transcript_summary(video_transcript)
    print(transcript_summary)
else:
    print("Could not generate summary as no transcript was available.")

# %% [markdown]
# V2 - TRANSCRIPTS WITH TIMESTAMP

# %%
# !pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.12.14)
# Downloading youtube_transcript_api-0.6.3-py3-none-any.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 16.6 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.3

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def download_youtube_transcript(video_id):
    try:
        # Fetch the available transcript languages
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to fetch transcript in the first available language
        transcript = None
        for transcript_info in transcript_list:
            try:
                transcript = transcript_info.fetch()
                print(f"Transcript found in language: {transcript_info.language}")
                break
            except Exception as inner_e:
                continue

        if not transcript:
            print("Could not fetch a transcript in any available language.")
            return

        # Print the structured output
        for entry in transcript:
            print({
                'text': entry['text'],
                'start_time': entry['start'],
                'duration': entry['duration']
            })
    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    video_id = 'boHg6quSZtI'
    download_youtube_transcript(video_id)

# %% [markdown]
# V2 - HYPER LINK TO REACH THE VIDEO PART

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def download_youtube_transcript(video_id):
    try:
        # Fetch the available transcript languages
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to fetch transcript in the first available language
        transcript = None
        for transcript_info in transcript_list:
            try:
                transcript = transcript_info.fetch()
                print(f"Transcript found in language: {transcript_info.language}")
                break
            except Exception as inner_e:
                continue

        if not transcript:
            print("Could not fetch a transcript in any available language.")
            return

        # Print the structured output with hyperlinks
        base_url = f"https://www.youtube.com/watch?v={video_id}&t="
        for entry in transcript:
            hyperlink = base_url + str(int(entry['start'])) + "s"
            print({
                'text': entry['text'],
                'start_time': entry['start'],
                'duration': entry['duration'],
                'hyperlink': hyperlink
            })
    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    video_id = 'boHg6quSZtI'
    download_youtube_transcript(video_id)
# Out:
# Transcript found in language: Telugu (auto-generated)
# {'text': 'హలో వెల్కమ్ టు అవర్ ఛానల్ మొత్తానికి', 'start_time': 0.4, 'duration': 6.399, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=0s'}
# {'text': 'అల్లు అర్జున్ గారు రిలీజ్ అయ్యారు ఇంటికి', 'start_time': 3.28, 'duration': 5.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=3s'}
# {'text': 'వచ్చారు ఒక', 'start_time': 6.799, 'duration': 5.361, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=6s'}
# {'text': 'రోజంతా జైల్లో ఉండాల్సిన తప్పైతే అల్లు', 'start_time': 9.2, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=9s'}
# {'text': 'అర్జున్ గారు చేయలేదు అన్నది నా వ్యక్తిగత', 'start_time': 12.16, 'duration': 5.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=12s'}
# {'text': 'అభిప్రాయం బట్ అగైన్ ఎందుకు జరిగింది ఏంటి', 'start_time': 14.08, 'duration': 6.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=14s'}
# {'text': 'అన్నది ఇంకా వారి విజ్ఞతకే వదిలేద్దాం మనం', 'start_time': 17.6, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=17s'}
# {'text': 'దాన్ని పట్టించుకోవాల్సిన అవసరం లేదు ఎంత', 'start_time': 20.16, 'duration': 4.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=20s'}
# {'text': 'విచిత్రంగా ఉందంటే అండి పరిస్థితి', 'start_time': 22.16, 'duration': 5.6, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=22s'}
# {'text': 'తెలంగాణలో డికే అరుణ గారు గాని లేకపోతే', 'start_time': 24.92, 'duration': 5.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=24s'}
# {'text': 'బండి సంజయ్ గారు గాని ప్రతి ఒక్క బిజెపి', 'start_time': 27.76, 'duration': 6.24, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=27s'}
# {'text': 'నాయకుడు అలాగే బిఆర్ఎస్ వాళ్ళు కూడా అల్లు', 'start_time': 30.08, 'duration': 5.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=30s'}
# {'text': 'అర్జున్ అరెస్ట్ ని తీవ్రంగా ఖండించారు', 'start_time': 34.0, 'duration': 5.68, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=34s'}
# {'text': 'కానీ ఆంధ్రాకు వచ్చే లోపు బిజెపి తరపున', 'start_time': 36.0, 'duration': 6.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=36s'}
# {'text': 'ఉన్న వాళ్ళు అంటే పురందేశ్వరి గాని', 'start_time': 39.68, 'duration': 4.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=39s'}
# {'text': 'లేకపోతే కూటంలో ఉన్న పవన్ కళ్యాణ్ గాని', 'start_time': 42.16, 'duration': 4.64, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=42s'}
# {'text': 'చంద్రబాబు గాని ఒక్క మాట కూడా', 'start_time': 44.64, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=44s'}
# {'text': 'మాట్లాడట్లేదు తెలంగాణలో ఉన్నది ఎవరు', 'start_time': 46.8, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=46s'}
# {'text': 'కాంగ్రెస్ కానీ కాంగ్రెస్ కి ఆపోజిట్ గా', 'start_time': 49.2, 'duration': 4.879, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=49s'}
# {'text': 'కూడా ఒక మాట కూడా మాట్లాడట్లేదు ఆంధ్రా', 'start_time': 51.68, 'duration': 5.519, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=51s'}
# {'text': 'నుంచి నాయకులు గాని కూటమి వాళ్ళు గాని మరి', 'start_time': 54.079, 'duration': 5.201, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=54s'}
# {'text': 'తెలంగాణలో బిజెపి వాళ్ళు మాట్లాడినప్పుడు', 'start_time': 57.199, 'duration': 4.721, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=57s'}
# {'text': 'ఆంధ్ర బిజెపి వాళ్ళు ఎందుకు మాట్లాడకూడదు', 'start_time': 59.28, 'duration': 6.64, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=59s'}
# {'text': 'పైగా సొంత బంధువు మొన్న థాంక్యూ పవన్', 'start_time': 61.92, 'duration': 5.68, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=61s'}
# {'text': 'బాబాయ్ అని కూడా అన్నాడు ఎవరు అల్లు', 'start_time': 65.92, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=65s'}
# {'text': 'అర్జున్ పవన్ కళ్యాణ్ ఇంతవరకు దాని', 'start_time': 67.6, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=67s'}
# {'text': 'గురించి ప్రస్తావన లేదు అదే ఇంతకుముందు', 'start_time': 70.32, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=70s'}
# {'text': 'చంద్రబాబు నాయుడు అరెస్ట్ అయితే ఆగమేఘాల', 'start_time': 72.4, 'duration': 4.399, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=72s'}
# {'text': 'మీద వెళ్లి రోడ్డు మీద పడుకొని దొర్లాడి', 'start_time': 74.88, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=74s'}
# {'text': 'పొర్లు దండాలు పెట్టి అది చేసి ఇది చేసి', 'start_time': 76.799, 'duration': 4.401, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=76s'}
# {'text': 'అడిగి నానా యాగీ చేశాడు కానీ ఇప్పుడు పిన్', 'start_time': 78.72, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=78s'}
# {'text': 'డ్రాప్ సైలెన్స్ అసలు ఏం మాటలు లేవు ఇంకా', 'start_time': 81.2, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=81s'}
# {'text': 'ఎందుకు ఏంటి అనేది వాళ్ళ విజ్ఞతకే', 'start_time': 83.28, 'duration': 5.199, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=83s'}
# {'text': 'వదిలేద్దాం ఇక్కడ ఈ వీడియో నేను చేసేదండి', 'start_time': 84.64, 'duration': 8.0, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=84s'}
# {'text': 'కొన్ని ఆసక్తి వ్యాఖ్యలు చేశారు రేవంత్', 'start_time': 88.479, 'duration': 6.801, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=88s'}
# {'text': 'రెడ్డి గారు మన తెలంగాణ ముఖ్యమంత్రి', 'start_time': 92.64, 'duration': 5.839, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=92s'}
# {'text': 'రేవంత్ రెడ్డి గారు అవి దుమారమే', 'start_time': 95.28, 'duration': 6.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=95s'}
# {'text': 'రేపుతున్నాయి కానీ ఎక్కడ దుమారం రేగుతుంది', 'start_time': 98.479, 'duration': 5.761, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=98s'}
# {'text': 'అన్నది ఇక్కడ చర్చనీయ అంశం నిన్న రేవంత్', 'start_time': 101.68, 'duration': 6.719, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=101s'}
# {'text': 'రెడ్డి గారు ఆ ఒక ఇండియా టుడే కాన్క్లేవ్', 'start_time': 104.24, 'duration': 4.919, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=104s'}
# {'text': 'లో', 'start_time': 108.399, 'duration': 3.201, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=108s'}
# {'text': 'అనుకుంటా కాన్క్లేవ్వా ఎన్క్లేవ్ ఐ డోంట్', 'start_time': 109.159, 'duration': 4.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=109s'}
# {'text': 'నో వాట్ ఎవర్ ద ప్రోగ్రాం నేమ్ బట్ ఐ', 'start_time': 111.6, 'duration': 5.159, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=111s'}
# {'text': 'థింక్ ఇట్స్ ఇండియా టుడే ఒక చర్చ వేదికలో', 'start_time': 113.439, 'duration': 5.761, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=113s'}
# {'text': 'మాట్లాడుతూ సినిమా యాక్టర్లు ఏమైనా', 'start_time': 116.759, 'duration': 4.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=116s'}
# {'text': 'సరిహద్దుల్లోకి వెళ్లి వాళ్ళు పోరాటాలు', 'start_time': 119.2, 'duration': 4.559, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=119s'}
# {'text': 'చేశారా వాళ్ళు ఏమైనా యుద్ధాలు చేసి', 'start_time': 121.119, 'duration': 4.881, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=121s'}
# {'text': 'దేశాన్ని కాపాడారా ఎందుకు వాళ్లకు అంత', 'start_time': 123.759, 'duration': 5.441, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=123s'}
# {'text': 'ఇంపార్టెన్స్ ఇవ్వాలి ఆ బాధిత కుటుంబాన్ని', 'start_time': 126.0, 'duration': 6.48, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=126s'}
# {'text': 'ఒకసారి మీరు ఊహించుకోండి వారి తరపున మీరు', 'start_time': 129.2, 'duration': 6.399, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=129s'}
# {'text': 'ఒక్కసారి ఆలోచించండి ఆ తల్లిని కోల్పోయాడు', 'start_time': 132.48, 'duration': 5.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=132s'}
# {'text': 'ఒక బిడ్డ ఇప్పటికి ఇంకా కోమాలోనే ఉన్నాడు', 'start_time': 135.599, 'duration': 5.841, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=135s'}
# {'text': 'అంటే ఇక్కడ రేవంత్ రెడ్డి గారి మాటలతో', 'start_time': 138.4, 'duration': 5.199, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=138s'}
# {'text': 'కొంతవరకు నేను ఏకీభవిస్తున్నాను చట్టాలు', 'start_time': 141.44, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=141s'}
# {'text': 'అన్నవి ఎవరికైనా ఒకేలాగా ఉండాలి ఇక్కడ', 'start_time': 143.599, 'duration': 4.801, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=143s'}
# {'text': 'చట్టాలు వీరి కోసం ఒకలాగా ఇంకొకరి కోసం', 'start_time': 145.84, 'duration': 5.119, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=145s'}
# {'text': 'ఒకలాగా ఉండాలని నేను ఎప్పుడూ అసలు అనను', 'start_time': 148.4, 'duration': 6.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=148s'}
# {'text': 'అండ్ ఆల్సో సినిమాలు అన్నవి నా వ్యక్తిగత', 'start_time': 150.959, 'duration': 5.041, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=150s'}
# {'text': 'అభిప్రాయం చాలా సార్లు మీకు చెప్పాను', 'start_time': 154.48, 'duration': 3.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=154s'}
# {'text': 'సినిమాలు అన్నవి కేవలం ఎంటర్టైన్మెంట్', 'start_time': 156.0, 'duration': 3.519, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=156s'}
# {'text': 'అండి సినిమాల నుంచి మనం నేర్చుకునేది', 'start_time': 157.84, 'duration': 3.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=157s'}
# {'text': 'సినిమాలు చూసి మన జీవితాన్ని మనం', 'start_time': 159.519, 'duration': 4.561, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=159s'}
# {'text': 'మార్చుకునేది ఏమీ ఉండదు మూడు గంటలు చూసామా', 'start_time': 161.2, 'duration': 4.64, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=161s'}
# {'text': 'ఆ చూసినప్పుడు హ్యాపీగా ఫీల్ అవుతాం ఆ', 'start_time': 164.08, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=164s'}
# {'text': 'సినిమా సూపర్ హిట్ అయితే ఒక నాలుగు ఐదు', 'start_time': 165.84, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=165s'}
# {'text': 'రోజులు ఎక్కువ మాట్లాడుకుంటాం తర్వాత ఐ', 'start_time': 167.36, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=167s'}
# {'text': 'విల్ బి బిజీ ఇన్ అవర్ లైఫ్ ఇప్పుడు పుష్ప', 'start_time': 169.12, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=169s'}
# {'text': 'చూసి నేను ఏం నేర్చుకుంటా అంటే', 'start_time': 171.2, 'duration': 2.64, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=171s'}
# {'text': 'నేర్చుకునేది లేదు ఏం లేదు ఆర్ఆర్ ఆర్', 'start_time': 172.4, 'duration': 3.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=172s'}
# {'text': 'చూసి ఏం నేర్చుకుంటాం అంటే ఏం లేదు ఎవరి', 'start_time': 173.84, 'duration': 2.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=173s'}
# {'text': 'సినిమా అయినా గాని జస్ట్ ఫర్', 'start_time': 175.76, 'duration': 2.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=175s'}
# {'text': 'ఎంటర్టైన్మెంట్ నేను చక్కటి ఉదాహరణ కూడా', 'start_time': 176.8, 'duration': 3.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=176s'}
# {'text': 'ఇంతకు ముందు చెప్పాను మహర్షి సినిమా చూసి', 'start_time': 178.48, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=178s'}
# {'text': 'వీకెండ్ ఫార్మింగ్ అని కొంతమంది', 'start_time': 180.56, 'duration': 3.52, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=180s'}
# {'text': 'బయలుదేరారు ఏది ఒక రెండు మూడు వారాల వరకు', 'start_time': 181.76, 'duration': 3.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=181s'}
# {'text': 'ఆ సినిమా ఉన్నంతవరకు తర్వాత వీకెండ్', 'start_time': 184.08, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=184s'}
# {'text': 'ఫార్మింగ్ లేదు ఏం లేదు సీ ఎవరీ వన్ విల్', 'start_time': 185.68, 'duration': 3.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=185s'}
# {'text': 'బి బిజీ ఇన్ లైఫ్ లైక్ యు నో మనకు', 'start_time': 187.92, 'duration': 3.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=187s'}
# {'text': 'కాలక్షేపం కోసం ఎస్ మూవీ ఇస్ పార్ట్ ఆఫ్', 'start_time': 189.44, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=189s'}
# {'text': 'అవర్ లైఫ్ బికాజ్ అదొక పెద్ద', 'start_time': 191.68, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=191s'}
# {'text': 'ఎంటర్టైన్మెంట్ మనకు ఇండియాలో అండ్ ఎవరీ', 'start_time': 193.84, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=193s'}
# {'text': 'వన్ లైక్స్ టు వాచ్ ఏ మూవీ ఓవర్ ది', 'start_time': 196.48, 'duration': 4.24, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=196s'}
# {'text': 'వీకెండ్ ఆర్ యు నో విత్ ఫ్యామిలీ మెంబర్స్', 'start_time': 198.56, 'duration': 4.0, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=198s'}
# {'text': 'అంతకంటే వాటికి నేను ఎక్కువ ఇంపార్టెన్స్', 'start_time': 200.72, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=200s'}
# {'text': 'కూడా ఇవ్వను కానీ ఇక్కడ రేవంత్ రెడ్డి', 'start_time': 202.56, 'duration': 5.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=202s'}
# {'text': 'గారు సరిహద్దుల్లో పోరాడారా అంటే అది', 'start_time': 205.12, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=205s'}
# {'text': 'కొంచెం హార్ష్ అని నాకు అనిపిస్తుంది', 'start_time': 208.4, 'duration': 3.68, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=208s'}
# {'text': 'వస్తుంది ఎందుకంటే ఇప్పుడు ఒక సినిమాకు 10', 'start_time': 209.92, 'duration': 4.319, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=209s'}
# {'text': 'కోట్లు కలెక్ట్ అవుతే మూడు కోట్లు జిఎస్టి', 'start_time': 212.08, 'duration': 3.68, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=212s'}
# {'text': 'కడుతున్నారు ఎవరి సినిమా వాళ్ళు', 'start_time': 214.239, 'duration': 4.161, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=214s'}
# {'text': 'గవర్నమెంట్ లకి ఆదాయం వస్తుంది ఆ వచ్చిన', 'start_time': 215.76, 'duration': 4.559, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=215s'}
# {'text': 'డబ్బుని వాళ్ళు ప్రజలకు మంచి పనుల కోసం', 'start_time': 218.4, 'duration': 5.199, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=218s'}
# {'text': 'కూడా ఉపయోగించొచ్చు సో మరీ సినిమాని తీసి', 'start_time': 220.319, 'duration': 5.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=220s'}
# {'text': 'పక్కన పడేయాల్సిన అవసరం అయితే లేదు బట్', 'start_time': 223.599, 'duration': 4.241, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=223s'}
# {'text': 'సినిమా అన్నది ప్యూర్లీ ఎంటర్టైన్మెంట్', 'start_time': 226.239, 'duration': 3.441, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=226s'}
# {'text': 'దాని వల్ల నేర్చుకొని మనం బాగుపడేది ఏమి', 'start_time': 227.84, 'duration': 3.679, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=227s'}
# {'text': 'ఉండదు కానీ ఒకటే నేను ఎప్పుడూ కూడా', 'start_time': 229.68, 'duration': 4.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=229s'}
# {'text': 'ఆలోచించేది ఏందంటే సినిమాల్ని సినిమా లాగే', 'start_time': 231.519, 'duration': 3.921, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=231s'}
# {'text': 'చూడాలి ఇప్పుడు మన ప్రత్యర్థుల సినిమా', 'start_time': 233.76, 'duration': 3.199, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=233s'}
# {'text': 'అయితే మనం దాన్ని తీసి పడేయాలి అని నేను', 'start_time': 235.44, 'duration': 2.799, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=235s'}
# {'text': 'ఎప్పుడూ అనుకోను ఎందుకంటే ఒకటి', 'start_time': 236.959, 'duration': 3.041, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=236s'}
# {'text': 'ఎంప్లాయ్మెంట్ క్రియేట్ చేస్తుంది సినిమా', 'start_time': 238.239, 'duration': 4.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=238s'}
# {'text': 'ఇండస్ట్రీ అనేది వేల కోట్ల టర్న్ ఓవర్', 'start_time': 240.0, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=240s'}
# {'text': 'ఉంది ఎంప్లాయ్మెంట్ క్రియేట్ చేస్తుంది', 'start_time': 242.319, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=242s'}
# {'text': 'అండ్ 10 మందికి ఉపాధి కల్పిస్తుంది అండ్', 'start_time': 243.84, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=243s'}
# {'text': 'ఆల్సో గవర్నమెంట్ కి టాక్స్ కడుతుంది ఆ', 'start_time': 246.159, 'duration': 4.561, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=246s'}
# {'text': 'దృష్టిలో చూస్తే సినిమాని తక్కువ చేసి', 'start_time': 248.72, 'duration': 4.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=248s'}
# {'text': 'చూడాల్సిన అవసరం లేదు ఇట్స్ లైక్ ఎనీ అదర్', 'start_time': 250.72, 'duration': 4.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=250s'}
# {'text': 'ప్రొఫెషన్ ప్రతి ఒక్క ప్రొఫెషన్ లో కూడా', 'start_time': 253.08, 'duration': 3.879, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=253s'}
# {'text': 'ప్లస్ లు మైనస్లు ఉంటాయి సినిమా', 'start_time': 255.68, 'duration': 3.839, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=255s'}
# {'text': 'ఇండస్ట్రీలో ప్లస్ లు మైనస్ లు ఉంటాయి సో', 'start_time': 256.959, 'duration': 5.761, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=256s'}
# {'text': 'రేవంత్ రెడ్డి అన్న మాటలతో నేను కొంతవరకు', 'start_time': 259.519, 'duration': 5.281, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=259s'}
# {'text': 'ఏకీభవిస్తాను కొంతవరకు నేను విభేదిస్తాను', 'start_time': 262.72, 'duration': 5.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=262s'}
# {'text': 'ఇక్కడ పాయింట్ ఏంటంటే చిరంజీవి గారు', 'start_time': 264.8, 'duration': 7.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=264s'}
# {'text': 'సినిమా ఇండస్ట్రీ తరపున తరపున జగన్ మోహన్', 'start_time': 268.56, 'duration': 5.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=268s'}
# {'text': 'రెడ్డి గారి ఇంటికి వెళ్లారు ఫస్ట్ టైం', 'start_time': 272.08, 'duration': 6.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=272s'}
# {'text': 'వెళ్ళినప్పుడు సాధరంగా ఆహ్వానించి భోజనం', 'start_time': 274.44, 'duration': 6.52, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=274s'}
# {'text': 'పెట్టి అన్ని మర్యాదలు చేసి పంపించారు', 'start_time': 278.16, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=278s'}
# {'text': 'జగన్ మోహన్ రెడ్డి గారి దంపతులు మళ్ళీ', 'start_time': 280.96, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=280s'}
# {'text': 'రెండవ సారి కొంతమంది సినిమా ఇండస్ట్రీ', 'start_time': 282.88, 'duration': 4.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=282s'}
# {'text': 'లోని పెద్దలతో ఐ థింక్ నాకు గుర్తుండి', 'start_time': 285.28, 'duration': 5.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=285s'}
# {'text': 'దిల్రాజు గారు పోసాని గారు ఆ మరి అదే', 'start_time': 287.04, 'duration': 6.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=287s'}
# {'text': 'ట్రిప్ లో మహేష్ బాబు గారు లేకపోతే', 'start_time': 291.12, 'duration': 4.0, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=291s'}
# {'text': 'ప్రభాస్ గారు వచ్చారో లేదో నాకు తెలియదు', 'start_time': 293.6, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=293s'}
# {'text': 'కానీ కొంతమందితో కలిసి వెళ్లారు ఎవరు', 'start_time': 295.12, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=295s'}
# {'text': 'చిరంజీవి గారు వెళ్ళినప్పుడు మాటల మధ్యలో', 'start_time': 296.88, 'duration': 6.0, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=296s'}
# {'text': 'ఏదో ఆ సందర్భం ఏంటో మనకు తెలియదు కానీ', 'start_time': 300.0, 'duration': 5.199, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=300s'}
# {'text': 'చిరంజీవి గారు మా సమస్యను పరిష్కరించండి', 'start_time': 302.88, 'duration': 5.039, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=302s'}
# {'text': 'అని చెప్పేసి ఆ ఒక ముఖ్యమంత్రికి దండం', 'start_time': 305.199, 'duration': 5.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=305s'}
# {'text': 'పెడుతూ వారు మాట్లాడారు ఎంత నానాయాగి', 'start_time': 307.919, 'duration': 5.201, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=307s'}
# {'text': 'చేశాడండి పవన్ కళ్యాణ్ మా అన్న చేత దండం', 'start_time': 310.639, 'duration': 4.881, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=310s'}
# {'text': 'పెట్టిస్తారా మా అన్న ఇది మా అన్న', 'start_time': 313.12, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=313s'}
# {'text': 'మెగాస్టారు మా అన్న అంత గొప్ప వ్యక్తి మా', 'start_time': 315.52, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=315s'}
# {'text': 'అన్న అంటే ఏంటి మా అన్న చేత దండం', 'start_time': 318.0, 'duration': 5.039, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=318s'}
# {'text': 'పెట్టిస్తారా మా అన్న పులి మా అన్న సింహము', 'start_time': 320.32, 'duration': 6.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=320s'}
# {'text': 'అని చెప్పేసి ఎంత నానాయాగి చేశారండి ఎక్కడ', 'start_time': 323.039, 'duration': 6.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=323s'}
# {'text': 'జగన్ మోహన్ రెడ్డి గారు వాళ్ళని తక్కువ', 'start_time': 327.12, 'duration': 4.24, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=327s'}
# {'text': 'చేసి మాట్లాడలేదు ఒక్క మాట కూడా అనలేదు', 'start_time': 329.199, 'duration': 5.121, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=329s'}
# {'text': 'ఎక్కడా తిట్టలేదు ఎక్కడ అసభ్య పదజాలం యూస్', 'start_time': 331.36, 'duration': 5.04, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=331s'}
# {'text': 'చేయలేదు జగన్ మోహన్ రెడ్డి గారు ఆ', 'start_time': 334.32, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=334s'}
# {'text': 'చిరంజీవి దా దండం పెట్టు అని చెప్పి కూడా', 'start_time': 336.4, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=336s'}
# {'text': 'అడగలేదు ఆ విషయం కూడా అసలు జగన్ మోహన్', 'start_time': 338.16, 'duration': 3.759, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=338s'}
# {'text': 'రెడ్డి గారు ప్రస్తావించలేదు చిరంజీవి', 'start_time': 340.72, 'duration': 5.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=340s'}
# {'text': 'గారే కృతజ్ఞత భావంతో దండం పెట్టారు ఈరోజు', 'start_time': 341.919, 'duration': 6.241, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=341s'}
# {'text': 'రేవంత్ రెడ్డి గారు అప్పుడు జగన్ మోహన్', 'start_time': 346.08, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=346s'}
# {'text': 'రెడ్డి గారు ఆంధ్రప్రదేశ్ ముఖ్యమంత్రి', 'start_time': 348.16, 'duration': 2.479, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=348s'}
# {'text': 'ఇప్పుడు రేవంత్ రెడ్డి గారు తెలంగాణకు', 'start_time': 349.36, 'duration': 3.2, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=349s'}
# {'text': 'ముఖ్యమంత్రి డైరెక్ట్ గా అన్నారు ఏందబ్బా', 'start_time': 350.639, 'duration': 3.601, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=350s'}
# {'text': 'మీ సినిమా యాక్టర్లు మీదేంది గొప్ప మీరు', 'start_time': 352.56, 'duration': 4.079, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=352s'}
# {'text': 'ఏమన్నా బార్డర్ లో పోయి దేశ సేవ చేశారా', 'start_time': 354.24, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=354s'}
# {'text': 'లేకపోతే యుద్ధాలను ఆపారా లేకపోతే అవతల', 'start_time': 356.639, 'duration': 4.161, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=356s'}
# {'text': 'వాళ్ళని అంటే ప్రత్యర్థులు ఏమైనా మీరు', 'start_time': 358.8, 'duration': 4.2, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=358s'}
# {'text': 'ఆపారా దేశాన్ని కాపాడారా రక్షించారా ఏం', 'start_time': 360.8, 'duration': 4.48, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=360s'}
# {'text': 'చేస్తున్నారు వ్యాపారం సినిమా అంటే', 'start_time': 363.0, 'duration': 3.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=363s'}
# {'text': 'వ్యాపారం మీరు డబ్బులు పెడుతున్నారు', 'start_time': 365.28, 'duration': 2.639, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=365s'}
# {'text': 'పెట్టుబడి మీకు డబ్బులు ఎందుకు', 'start_time': 366.72, 'duration': 2.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=366s'}
# {'text': 'వస్తున్నాయి అంతకంటే మీరు ఏం చేస్తున్నారు', 'start_time': 367.919, 'duration': 3.761, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=367s'}
# {'text': 'అని చెప్పేసి ప్రతి ఒక్క సినిమా యాక్టర్', 'start_time': 369.28, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=369s'}
# {'text': 'ని తక్కువ చేసి మాట్లాడాడు రేవంత్ రెడ్డి', 'start_time': 371.68, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=371s'}
# {'text': 'అది తక్కువ చేసి మాట్లాడినట్టే అందులో', 'start_time': 374.16, 'duration': 3.68, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=374s'}
# {'text': 'మెగా స్టార్లు ఉంటారు సూపర్ స్టార్లు', 'start_time': 376.0, 'duration': 3.919, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=376s'}
# {'text': 'ఉంటారు మైటీ స్టార్లు ఉంటారు ఆ స్టార్ ఈ', 'start_time': 377.84, 'duration': 4.799, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=377s'}
# {'text': 'స్టార్ అందరి స్టార్లని ఏకి పారేశాడు', 'start_time': 379.919, 'duration': 4.881, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=379s'}
# {'text': 'రేవంత్ రెడ్డి ఇప్పుడు మరి ఇండస్ట్రీలో', 'start_time': 382.639, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=382s'}
# {'text': 'ఉన్న వాళ్ళు ఎందుకు బయటికి వచ్చి ఒక్క మాట', 'start_time': 384.8, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=384s'}
# {'text': 'కూడా మాట్లాడట్లేదు అసలు రేవంత్ రెడ్డి', 'start_time': 387.199, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=387s'}
# {'text': 'నీకేం హక్కు ఉంది రేవంత్ రెడ్డి నువ్వు మా', 'start_time': 389.12, 'duration': 4.639, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=389s'}
# {'text': 'అన్న మెగా స్టార్ మా అన్న అన్నావు మా', 'start_time': 391.759, 'duration': 4.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=391s'}
# {'text': 'రెండో అన్న పవర్ స్టార్ ఆయన అన్నావు నేను', 'start_time': 393.759, 'duration': 5.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=393s'}
# {'text': 'పవర్ స్టార్ నన్ను అన్నావు నా అన్న కొడుకు', 'start_time': 395.919, 'duration': 5.201, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=395s'}
# {'text': 'మెగా పవర్ స్టార్ ఇప్పుడు గ్లోబల్ స్టార్', 'start_time': 399.199, 'duration': 3.601, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=399s'}
# {'text': 'అతన్ని కూడా అన్నావు అంటే మేమంతా సినిమా', 'start_time': 401.12, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=401s'}
# {'text': 'వాళ్ళం అంత పనికిరాని వాళ్ళమా అంత వేస్ట్', 'start_time': 402.8, 'duration': 3.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=402s'}
# {'text': 'గాలమా అంత దద్దమ్మలమా అంత చౌటలమా అంత', 'start_time': 404.56, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=404s'}
# {'text': 'వెదవలమా అని ఈరోజు బయటికి వచ్చి నానా యాగి', 'start_time': 406.72, 'duration': 4.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=406s'}
# {'text': 'చేసి రోడ్డు మీద పండుకొని పొర్లాడి దొర్లి', 'start_time': 409.36, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=409s'}
# {'text': 'పొర్లు దండాలు పెట్టి అలిగి గీ పెట్టి', 'start_time': 411.68, 'duration': 5.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=411s'}
# {'text': 'దాన్ని నానా రాద్దాంతం ఎందుకు చేయడం లేదు', 'start_time': 414.16, 'duration': 6.479, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=414s'}
# {'text': 'ఎందుకు చేయడం లేదు ఆ ఆ రోజు ఒక', 'start_time': 417.52, 'duration': 6.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=417s'}
# {'text': 'ముఖ్యమంత్రిని పట్టుకొని చిరంజీవి గారు', 'start_time': 420.639, 'duration': 5.041, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=420s'}
# {'text': 'థాంక్స్ అని దండం పెట్టిరు అది తప్పేం', 'start_time': 423.68, 'duration': 4.079, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=423s'}
# {'text': 'కాదు ఒక ముఖ్యమంత్రి స్థాయి వ్యక్తికి', 'start_time': 425.68, 'duration': 3.919, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=425s'}
# {'text': 'ఎవరైనా దండాలు పెడతారు అది తప్పుగా మా', 'start_time': 427.759, 'duration': 4.081, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=427s'}
# {'text': 'అన్న చేత పెట్టించుకుంటాడు మా అన్న పెద్ద', 'start_time': 429.599, 'duration': 4.401, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=429s'}
# {'text': 'పులి మా అన్న సింహము మా అన్న తురుము మా', 'start_time': 431.84, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=431s'}
# {'text': 'అన్న పుట్టసిన ఇది అది ఇది అన్నారు కదా', 'start_time': 434.0, 'duration': 3.759, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=434s'}
# {'text': 'ఈరోజు సినిమా ఇండస్ట్రీ వాళ్ళని అందరిని', 'start_time': 435.68, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=435s'}
# {'text': 'అవుట్ రేట్ గా రేవంత్ రెడ్డి ఇంకొక మాట', 'start_time': 437.759, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=437s'}
# {'text': 'కూడా అన్నాడండి ఎవరు మీ ఫేవరెట్ హీరో అంటే', 'start_time': 440.4, 'duration': 3.6, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=440s'}
# {'text': 'ఒకప్పుడు సూపర్ స్టార్ కృష్ణ నా ఫేవరెట్', 'start_time': 442.479, 'duration': 3.361, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=442s'}
# {'text': 'హీరో ఇప్పుడు ఎవరు లేరు నేనే పెద్ద స్టార్', 'start_time': 444.0, 'duration': 4.0, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=444s'}
# {'text': 'ని వాళ్ళకంటే నాకే ఫ్యాన్స్ ఉంటారు వాళ్ళు', 'start_time': 445.84, 'duration': 4.079, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=445s'}
# {'text': 'ఏంది పుట్టగోజులోది అన్నట్లు మాట అన్నాడు', 'start_time': 448.0, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=448s'}
# {'text': 'యాస్ ఇట్ ఇస్ గా మాట్లాడాడు హిందీలో ఇంకా', 'start_time': 449.919, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=449s'}
# {'text': 'మరి సిగ్గు లేదా సినిమా ఇండస్ట్రీ కి', 'start_time': 452.72, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=452s'}
# {'text': 'సిగ్గు లేదా చేమ చచ్చిందా ఏమైనాడు పవన్', 'start_time': 454.479, 'duration': 5.921, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=454s'}
# {'text': 'కళ్యాణ్ పవర్ స్టార్ పవర్ స్టార్ అని', 'start_time': 457.44, 'duration': 6.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=457s'}
# {'text': 'ఎగురు గంతులేయ్ ఇంకా మీ హైదరాబాద్ లోనే', 'start_time': 460.4, 'duration': 4.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=460s'}
# {'text': 'కదా మీ ఇల్లు హైదరాబాద్ లోనే ఉంది పో', 'start_time': 463.52, 'duration': 3.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=463s'}
# {'text': 'పోరాడు ట్యాంక్ బండు దగ్గరికి పోయి నిరసన', 'start_time': 465.36, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=465s'}
# {'text': 'తెలియజేయ్ పండుకో దొర్లాడు ఏం ఏంటి', 'start_time': 467.44, 'duration': 4.64, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=467s'}
# {'text': 'చేయడంలే సిగ్గు లేదు ప్రతి దాన్ని', 'start_time': 469.68, 'duration': 5.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=469s'}
# {'text': 'రాజకీయాలకు నిజంగా అండి మోస్ట్ డేంజరస్', 'start_time': 472.08, 'duration': 7.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=472s'}
# {'text': 'వ్యక్తులు ఎవరెవరంటే ఫస్ట్ చిరంజీవి రెండు', 'start_time': 475.52, 'duration': 6.0, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=475s'}
# {'text': 'పవన్ కళ్యాణ్ వీళ్ళు చాలా చాలా డేంజర్', 'start_time': 479.44, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=479s'}
# {'text': 'అంటే సమాజానికి చాలా డేంజర్ అని రాసి', 'start_time': 481.52, 'duration': 3.519, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=481s'}
# {'text': 'పెట్టుకోండి చిరంజీవికి అన్ని సకల', 'start_time': 483.28, 'duration': 3.759, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=483s'}
# {'text': 'మర్యాదలు చేసి అంత మంచిగా చూసుకుంటే', 'start_time': 485.039, 'duration': 4.081, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=485s'}
# {'text': 'చిరంజీవి ఏమంటాడండి నోరు తెరిచినాడా మా', 'start_time': 487.039, 'duration': 3.921, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=487s'}
# {'text': 'ఆయన దండం పెట్టాడని పవన్ కళ్యాణ్ ఇంత నానా', 'start_time': 489.12, 'duration': 3.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=489s'}
# {'text': 'యాగీ చేస్తుంటే కనీసం ఒక రోజు బయటికి', 'start_time': 490.96, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=490s'}
# {'text': 'వచ్చి లేదులే పవన్ కళ్యాణ్ కి తెలియదు ఆ', 'start_time': 492.4, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=492s'}
# {'text': 'వైయస్ జగన్ దంపతులు నన్ను ఎంత బాగా', 'start_time': 495.28, 'duration': 4.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=495s'}
# {'text': 'చూసుకున్నారని అది నాకు తెలుసు అన్ని', 'start_time': 497.28, 'duration': 3.84, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=497s'}
# {'text': 'మర్యాదలు చేశారని ఏ రోజైనా బయటికి వచ్చి', 'start_time': 499.36, 'duration': 3.519, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=499s'}
# {'text': 'నోరు తెరిచి చెప్పినాడా వెరీ డేంజరస్ అండ్', 'start_time': 501.12, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=501s'}
# {'text': 'కన్నింగ్ ఫిలిం చిరంజీవి నిజంగా', 'start_time': 502.879, 'duration': 3.521, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=502s'}
# {'text': 'చెప్తున్నానండి ఇంకా పవన్ కళ్యాణ్', 'start_time': 504.56, 'duration': 3.359, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=504s'}
# {'text': 'చెప్పినన్ని అబద్ధాలు ప్రపంచంలో ఎవరు', 'start_time': 506.4, 'duration': 3.04, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=506s'}
# {'text': 'చెప్పిండ్రు 30 వేల మంది అమ్మాయిలు మిస్', 'start_time': 507.919, 'duration': 2.481, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=507s'}
# {'text': 'అయినారు', 'start_time': 509.44, 'duration': 3.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=509s'}
# {'text': '30000 మంది అమ్మాయిలు అది కూడా క్లియర్ గా', 'start_time': 510.4, 'duration': 4.879, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=510s'}
# {'text': 'అక్రమ రవాణా చేశారు అమ్మాయిలను అని', 'start_time': 513.36, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=513s'}
# {'text': 'చెప్పినారు ఏది ఇంట్లో నుంచి అలిగి', 'start_time': 515.279, 'duration': 3.281, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=515s'}
# {'text': 'వెళ్ళిపోయో లేకపోతే మతిస్థిమితం లేకుండా', 'start_time': 516.8, 'duration': 3.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=516s'}
# {'text': 'వెళ్ళిపోయో లేకపోతే ఇంకొక రకంగా ఇంకొక', 'start_time': 518.56, 'duration': 5.2, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=518s'}
# {'text': 'రకంగా ఆచూకి తప్పిపోయిన వాళ్ళు కాదు', 'start_time': 520.56, 'duration': 5.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=520s'}
# {'text': 'అమ్మాయిల్ని అమ్మారు 30 వేల మంది', 'start_time': 523.76, 'duration': 3.92, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=523s'}
# {'text': 'అమ్మాయిల్ని అమ్మారు హ్యూమన్ ట్రాఫికింగ్', 'start_time': 525.68, 'duration': 4.48, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=525s'}
# {'text': 'అని చెప్పాడు చివరికి ఎంత అని తెలిసింది', 'start_time': 527.68, 'duration': 4.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=527s'}
# {'text': '46 మంది తప్పిపోయినారు 34 కేసులు', 'start_time': 530.16, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=530s'}
# {'text': 'రిజిస్టర్ అయినాయి గత ఐదేళ్లలో తప్పిపోయిన', 'start_time': 532.48, 'duration': 3.52, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=532s'}
# {'text': 'వాళ్ళు వేరే హ్యూమన్ ట్రాఫికింగ్ వల్ల', 'start_time': 534.48, 'duration': 3.359, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=534s'}
# {'text': 'తప్పిపోయిన వాళ్ళు 46 మంది అయితే 34', 'start_time': 536.0, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=536s'}
# {'text': 'కేసులు రిజిస్టర్ అయినాయి అది అబద్ధం మా', 'start_time': 537.839, 'duration': 4.961, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=537s'}
# {'text': 'ఆయన దండం పెట్టాడు అన్నది అబద్ధం ప్రతిదీ', 'start_time': 540.32, 'duration': 5.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=540s'}
# {'text': 'అబద్ధ పునాదుల మీద ఈరోజు ఉప ముఖ్యమంత్రి', 'start_time': 542.8, 'duration': 5.039, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=542s'}
# {'text': 'అయినాడు ఏది ఏది నిజం చెప్పినాడు చెప్పండి', 'start_time': 545.76, 'duration': 4.32, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=545s'}
# {'text': 'షణ్ముఖ వ్యూహం అన్నాడు ఏందో నియోజకవర్గంలో', 'start_time': 547.839, 'duration': 3.841, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=547s'}
# {'text': '500 మందికి ఒక్కొక్కరికి 10 లక్షలు ఇస్తా', 'start_time': 550.08, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=550s'}
# {'text': 'అన్నాడు ఇచ్చినాడా ఆ ఇచ్చినాడా ప్రతి', 'start_time': 551.68, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=551s'}
# {'text': 'దాన్ని తీసుకొచ్చేది పెద్దది చేసేది అరిచి', 'start_time': 554.48, 'duration': 4.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=554s'}
# {'text': 'గీ పెట్టేది ఏడండి అసలు సాయి ధరం తేజు', 'start_time': 556.56, 'duration': 4.48, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=556s'}
# {'text': 'నాకు తెలిసి అదేదో ఇప్పుడు ఫ్లై ఓవర్ ఉంది', 'start_time': 559.44, 'duration': 5.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=559s'}
# {'text': 'దుర్గం చెరువు ఫ్లై ఓవరా ఆడ బైక్ లో పోతూ', 'start_time': 561.04, 'duration': 5.359, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=561s'}
# {'text': 'పోతూ జారి పడ్డాడు చాలా మంది ఏమంటారంటే', 'start_time': 564.56, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=564s'}
# {'text': 'తాగి డ్రైవింగ్ చేసినాడు అని ఇంకా మనకు', 'start_time': 566.399, 'duration': 3.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=566s'}
# {'text': 'తెలియదు కాబట్టి నేను మాట్లాడట్లేదు నేను', 'start_time': 568.0, 'duration': 3.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=568s'}
# {'text': 'తాగి డ్రైవింగ్ చేశాను ఆరోపణ కూడా', 'start_time': 569.519, 'duration': 4.561, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=569s'}
# {'text': 'చేయట్లేదు కింద పడ్డాడు ఏమి కాలేదు సంతోషం', 'start_time': 571.12, 'duration': 5.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=571s'}
# {'text': 'వి ఆల్ ప్రేడ్ ఫర్ హిస్ స్పీడీ రికవరీ', 'start_time': 574.08, 'duration': 4.879, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=574s'}
# {'text': 'అండ్ బాగా వచ్చాడు అతను రిపబ్లికన్ ఒక', 'start_time': 576.24, 'duration': 4.48, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=576s'}
# {'text': 'సినిమా తీస్తే అతను హాస్పిటల్ లో ఉన్నాడని', 'start_time': 578.959, 'duration': 3.761, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=578s'}
# {'text': 'చీఫ్ గెస్ట్ గా పవన్ కళ్యాణ్ వచ్చాడు', 'start_time': 580.72, 'duration': 4.28, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=580s'}
# {'text': 'అక్కడ కూడా జరిగింది', 'start_time': 582.72, 'duration': 5.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=582s'}
# {'text': 'తెలంగాణలో ఆ దుర్గంచే ఉండేది', 'start_time': 585.0, 'duration': 5.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=585s'}
# {'text': 'హైదరాబాదులో ఆ బైక్ యాక్సిడెంట్ అయింది', 'start_time': 588.12, 'duration': 4.159, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=588s'}
# {'text': 'తెలంగాణలో', 'start_time': 590.72, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=590s'}
# {'text': 'ఆంధ్ర ప్రభుత్వం మీద జగన్ మోహన్ రెడ్డి', 'start_time': 592.279, 'duration': 4.921, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=592s'}
# {'text': 'గారి మీద విమర్శలు చేసి ఓ అని కై కై కై', 'start_time': 595.12, 'duration': 4.719, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=595s'}
# {'text': 'అని ఎగిరినాడు ఆ రోజు అసలు సంబంధమే లేదు', 'start_time': 597.2, 'duration': 5.04, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=597s'}
# {'text': 'అంటే ఎంత దరిద్రపు మనస్తత్వం అంటే పవన్', 'start_time': 599.839, 'duration': 4.881, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=599s'}
# {'text': 'కళ్యాణ్ ది ప్రతి దానికి జగన్ మోహన్', 'start_time': 602.24, 'duration': 3.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=602s'}
# {'text': 'రెడ్డి గారిని టార్గెట్ చేయాలా మా ఆయన', 'start_time': 604.72, 'duration': 2.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=604s'}
# {'text': 'దండం పెట్టిన టార్గెట్ చేయాలి జగన్ మోహన్', 'start_time': 606.0, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=606s'}
# {'text': 'రెడ్డి గారిని అసలు ఎవరో ఏ విధంగానో', 'start_time': 607.6, 'duration': 3.2, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=607s'}
# {'text': 'అమ్మాయిలు తప్పిపోయినా గాని జగన్ మోహన్', 'start_time': 609.44, 'duration': 3.44, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=609s'}
# {'text': 'రెడ్డి గారిని బ్లేమ్ చేయాలా ఆ ఇప్పుడు', 'start_time': 610.8, 'duration': 4.159, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=610s'}
# {'text': 'అతను 500 మందికి 10 లక్షలు ఎందుకు', 'start_time': 612.88, 'duration': 3.36, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=612s'}
# {'text': 'ఇవ్వలేదు అంటే జగన్ మోహన్ రెడ్డి డబ్బులు', 'start_time': 614.959, 'duration': 2.801, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=614s'}
# {'text': 'పెట్టి పోలేదు అని చెప్పేసి దాన్ని కూడా', 'start_time': 616.24, 'duration': 2.96, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=616s'}
# {'text': 'మళ్ళా జగన్ మోహన్ రెడ్డి గారిని టార్గెట్', 'start_time': 617.76, 'duration': 3.199, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=617s'}
# {'text': 'చేయాలా చంద్రబాబు నాయుడు లప్పం పెట్టి', 'start_time': 619.2, 'duration': 4.079, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=619s'}
# {'text': 'పోయినాడు ఆహా 2019 లో జగన్ మోహన్ రెడ్డి', 'start_time': 620.959, 'duration': 3.521, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=620s'}
# {'text': 'గారు అధికారంలోకి వచ్చినప్పుడు చంద్రబాబు', 'start_time': 623.279, 'duration': 3.441, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=623s'}
# {'text': 'నాయుడు పెద్ద ఖజానా మొత్తం ఒక 50 లక్షల', 'start_time': 624.48, 'duration': 4.16, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=624s'}
# {'text': 'కోట్లు బ్యాంకులో పెట్టి పోయినాడు ఇప్పుడు', 'start_time': 626.72, 'duration': 4.4, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=626s'}
# {'text': 'మళ్ళా వచ్చేసి ఇయ్యలేకుండాం రోడ్లకు', 'start_time': 628.64, 'duration': 5.04, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=628s'}
# {'text': 'గుంతలకు మరమతులు చేయలేకుండాం సిగ్గుండాలా', 'start_time': 631.12, 'duration': 5.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=631s'}
# {'text': 'అబద్ధాల పునాదుల మీద అధికారంలోకి వస్తే', 'start_time': 633.68, 'duration': 5.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=633s'}
# {'text': 'అది శాశ్వతం కాదు పవన్ కళ్యాణ్', 'start_time': 636.88, 'duration': 4.079, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=636s'}
# {'text': 'గుర్తుపెట్టుకోండి దమ్ము ధైర్యం ఉంటే', 'start_time': 638.8, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=638s'}
# {'text': 'కలేజా ఉంటే సినిమా ఇండస్ట్రీ వాళ్ళందరిని', 'start_time': 640.959, 'duration': 4.721, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=640s'}
# {'text': 'ఇట్లా తిట్టిన రేవంత్ రెడ్డిని ఎస్', 'start_time': 643.68, 'duration': 3.839, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=643s'}
# {'text': 'తిట్టినట్లే ఏం మీరేం బార్డర్ లోకి పోయి', 'start_time': 645.68, 'duration': 3.76, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=645s'}
# {'text': 'ఏమైనా యుద్ధాలు చేసి దేశాలు కాపాడినారా', 'start_time': 647.519, 'duration': 3.361, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=647s'}
# {'text': 'మీరు వ్యాపారం చేస్తున్నారు పెట్టుబడి', 'start_time': 649.44, 'duration': 2.639, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=649s'}
# {'text': 'పెడుతున్నారు డబ్బులు వస్తున్నాయి అంతకంటే', 'start_time': 650.88, 'duration': 2.8, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=650s'}
# {'text': 'మీరు పీకింది ఏంది పందిరేసింది ఏంది అని', 'start_time': 652.079, 'duration': 3.041, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=652s'}
# {'text': 'చెప్పేసి రేవంత్ రెడ్డి అన్నాడు దమ్ము', 'start_time': 653.68, 'duration': 4.64, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=653s'}
# {'text': 'ధైర్యం ఉంటే ఈరోజు పోయి పవన్ కళ్యాణ్', 'start_time': 655.12, 'duration': 6.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=655s'}
# {'text': 'బొరుగు గట్టిగా మురుగు అరువు గీ పెట్టు', 'start_time': 658.32, 'duration': 5.759, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=658s'}
# {'text': 'రోడ్డు మీద పండుకో దొర్లు పొర్లు దండాలు', 'start_time': 662.0, 'duration': 4.04, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=662s'}
# {'text': 'పెట్టు అవి ఏమి ఉండదు పిన్ డ్రాప్', 'start_time': 664.079, 'duration': 4.721, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=664s'}
# {'text': 'సైలెన్స్ మళ్ళా పోనీ వాళ్ళు ఏమన్నా సొంత', 'start_time': 666.04, 'duration': 4.359, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=666s'}
# {'text': 'పార్టీ అంటే ఇదే దౌర్భాగ్యం దరిద్రం', 'start_time': 668.8, 'duration': 4.08, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=668s'}
# {'text': 'ఏందంటే రాజకీయాలు ఎట్లా ఏడ్చినాయి అంటే', 'start_time': 670.399, 'duration': 4.401, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=670s'}
# {'text': 'బిజెపి కి బద్ద శత్రువు కాంగ్రెస్', 'start_time': 672.88, 'duration': 4.079, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=672s'}
# {'text': 'కాంగ్రెస్ ప్రభుత్వం తెలంగాణలో ఉంది', 'start_time': 674.8, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=674s'}
# {'text': 'బిజెపి కూటమిలో పవన్ కళ్యాణ్ ఉన్నాడు కానీ', 'start_time': 676.959, 'duration': 4.641, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=676s'}
# {'text': 'పవన్ కళ్యాణ్ పోయి కాంగ్రెస్ రేవంత్', 'start_time': 679.68, 'duration': 5.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=679s'}
# {'text': 'రెడ్డిని ఒక మాట కూడా అనడు కర్మ కాదండి', 'start_time': 681.6, 'duration': 6.479, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=681s'}
# {'text': 'రాజకీయాలు అన్నవి సొంత లాభాల కోసం ఏదైనా', 'start_time': 684.8, 'duration': 5.52, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=684s'}
# {'text': 'కక్షలు కార్పణ్యాలు తీర్చుకోవడం కోసం', 'start_time': 688.079, 'duration': 4.641, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=688s'}
# {'text': 'పర్సనల్ ఈగోల్ ని సాటిస్ఫై చేయడం కోసం ఈ', 'start_time': 690.32, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=690s'}
# {'text': 'రాజకీయాలు అన్నవి ఇప్పుడు కొత్త మలుపులు', 'start_time': 692.72, 'duration': 4.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=692s'}
# {'text': 'తిరిగాయండి ఇది అష్ట దరిద్రం దౌర్భాగ్యం', 'start_time': 695.04, 'duration': 5.039, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=695s'}
# {'text': 'రాష్ట్రానికి పట్టిన శని రాష్ట్ర ప్రజలు', 'start_time': 697.6, 'duration': 5.12, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=697s'}
# {'text': 'చేసుకున్న కర్మ అది మాత్రం గ్యారెంటీగా', 'start_time': 700.079, 'duration': 4.561, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=700s'}
# {'text': 'చెప్పగలను ఇంకా అంతకంటే మనం మాట్లాడాల్సిన', 'start_time': 702.72, 'duration': 4.239, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=702s'}
# {'text': 'పని లేదు రేవంత్ రెడ్డి తిట్టిన ఒక్కడికి', 'start_time': 704.64, 'duration': 4.56, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=704s'}
# {'text': 'కూడా ధైర్యం లేదు అని మాత్రం మనం', 'start_time': 706.959, 'duration': 4.081, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=706s'}
# {'text': 'అనుకోవాలి ఇంకా అంతకంటే వేరే ఆప్షన్ లేదు', 'start_time': 709.2, 'duration': 4.72, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=709s'}
# {'text': 'అది', 'start_time': 711.04, 'duration': 2.88, 'hyperlink': 'https://www.youtube.com/watch?v=boHg6quSZtI&t=711s'}

# %% [markdown]
# V2 - TRANSCRIPTS TO GOOGLE DRIVE

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import os

def save_transcripts_to_folder(video_id, folder_path):
    try:
        # Fetch the available transcript languages
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to fetch transcript in the first available language
        transcript = None
        for transcript_info in transcript_list:
            try:
                transcript = transcript_info.fetch()
                print(f"Transcript found in language: {transcript_info.language}")
                break
            except Exception:
                continue

        if not transcript:
            print("Could not fetch a transcript in any available language.")
            return

        # Ensure the folder exists
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Save the transcript to a file
        transcript_file = os.path.join(folder_path, f"transcript_{video_id}.txt")
        print(f"Saving file to: {transcript_file}")  # Debug print
        with open(transcript_file, 'w', encoding='utf-8') as file:
            for entry in transcript:
                file.write(f"{entry['start']} - {entry['duration']}: {entry['text']}\n")

        print(f"Transcript saved to {transcript_file}")
    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    from google.colab import drive
    drive.mount('/content/drive')  # Mount Google Drive
    video_id = 'boHg6quSZtI'  # Replace with your YouTube video ID
    folder_path = '/content/drive/My Drive/YT'  # Google Drive folder path
    save_transcripts_to_folder(video_id, folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Transcript found in language: Telugu (auto-generated)
# Saving file to: /content/drive/My Drive/YT/transcript_boHg6quSZtI.txt
# Transcript saved to /content/drive/My Drive/YT/transcript_boHg6quSZtI.txt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# V2 - TRANSCRIPTS TO AZURE BLOB

# %%
# !pip install azure-storage-blob

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from azure.storage.blob import BlobServiceClient
import os

def save_transcripts_to_blob(video_id, connection_string, container_name):
    try:
        # Fetch the available transcript languages
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to fetch transcript in the first available language
        transcript = None
        for transcript_info in transcript_list:
            try:
                transcript = transcript_info.fetch()
                print(f"Transcript found in language: {transcript_info.language}")
                break
            except Exception:
                continue

        if not transcript:
            print("Could not fetch a transcript in any available language.")
            return

        # Create the transcript content as a string
        transcript_content = ""
        for entry in transcript:
            transcript_content += f"{entry['start']} - {entry['duration']}: {entry['text']}\n"

        # Upload the transcript to Azure Blob Storage
        blob_name = f"transcript_{video_id}.txt"
        blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

        blob_client.upload_blob(transcript_content, overwrite=True)

        print(f"Transcript uploaded to blob: {blob_name} in container: {container_name}")
    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    video_id = 'boHg6quSZtI'  # Replace with your YouTube video ID
    connection_string = (AZ_STR)  # Replace with your Azure Storage connection string
    container_name = 'content'  # Replace with your Azure Blob container name
    save_transcripts_to_blob(video_id, connection_string, container_name)

# %% [markdown]
# V2 - TRASCRIPTS WITH HYPERLINKS TO AZURE BLOB

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from azure.storage.blob import BlobServiceClient
import os

def save_transcripts_to_blob(video_id, connection_string, container_name):
    try:
        # Fetch the available transcript languages
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to fetch transcript in the first available language
        transcript = None
        for transcript_info in transcript_list:
            try:
                transcript = transcript_info.fetch()
                print(f"Transcript found in language: {transcript_info.language}")
                break
            except Exception:
                continue

        if not transcript:
            print("Could not fetch a transcript in any available language.")
            return

        # Create the transcript content as a string with hyperlinks
        base_url = f"https://www.youtube.com/watch?v={video_id}&t="
        transcript_content = ""
        for entry in transcript:
            hyperlink = base_url + str(int(entry['start'])) + "s"
            transcript_content += f"{entry['start']} - {entry['duration']}: {entry['text']}\nHyperlink: {hyperlink}\n\n"

        # Upload the transcript to Azure Blob Storage
        blob_name = f"transcript_{video_id}.txt"
        blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

        blob_client.upload_blob(transcript_content, overwrite=True)

        print(f"Transcript uploaded to blob: {blob_name} in container: {container_name}")
    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

def download_youtube_transcript(video_id):
    try:
        # Fetch the available transcript languages
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Try to fetch transcript in the first available language
        transcript = None
        for transcript_info in transcript_list:
            try:
                transcript = transcript_info.fetch()
                print(f"Transcript found in language: {transcript_info.language}")
                break
            except Exception as inner_e:
                continue

        if not transcript:
            print("Could not fetch a transcript in any available language.")
            return

        # Print the structured output with hyperlinks
        base_url = f"https://www.youtube.com/watch?v={video_id}&t="
        for entry in transcript:
            hyperlink = base_url + str(int(entry['start'])) + "s"
            print({
                'text': entry['text'],
                'start_time': entry['start'],
                'duration': entry['duration'],
                'hyperlink': hyperlink
            })
    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    video_id = 'boHg6quSZtI'  # Replace with your YouTube video ID
    connection_string = (AZ_STR)  # Replace with your Azure Storage connection string
    container_name = 'contentwithlinks'  # Replace with your Azure Blob container name
    save_transcripts_to_blob(video_id, connection_string, container_name)
    download_youtube_transcript(video_id)

# %% [markdown]
# V2 - SEARCH FOR DILOG IN VIDEO AND GENERATE HYPER LINK - GOOGLE DRIVE AS SOURCE
#
# **NOT GREAT ENOUGH TO UNDERSTAND THE CONTEXT HENCE NOT THE PREFFERED METHOD 😞**

# %%
# !pip install rapidfuzz
# !pip install indic-transliteration
# Out:
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (3.11.0)
# Collecting indic-transliteration
#   Downloading indic_transliteration-2.3.68-py3-none-any.whl.metadata (1.4 kB)
# Collecting backports.functools-lru-cache (from indic-transliteration)
#   Downloading backports.functools_lru_cache-2.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from indic-transliteration) (2024.11.6)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from indic-transliteration) (0.15.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from indic-transliteration) (0.10.2)
# Collecting roman (from indic-transliteration)
#   Downloading roman-4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer->indic-transliteration) (8.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from typer->indic-transliteration) (4.12.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->indic-transliteration) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer->indic-transliteration) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer->indic-transliteration) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer->indic-transliteration) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->indic-transliteration) (0.1.2)
# Downloading indic_transliteration-2.3.68-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 2.9 MB/s eta 0:00:00
# Downloading backports.functools_lru_cache-2.0.0-py2.py3-none-any.whl (6.7 kB)
# Downloading roman-4.2-py3-none-any.whl (5.5 kB)
# Installing collected packages: roman, backports.functools-lru-cache, indic-transliteration
# Successfully installed backports.functools-lru-cache-2.0.0 indic-transliteration-2.3.68 roman-4.2

# %%
from rapidfuzz import fuzz
import os
from indic_transliteration import sanscript
from indic_transliteration.sanscript import SchemeMap, SCHEMES, transliterate

def search_transcript_with_fuzzy_matching_from_file(video_id, search_term, folder_path, threshold=70):
    try:
        # Transliterate the search term to Telugu
        transliterated_term = transliterate(search_term, sanscript.ITRANS, sanscript.TELUGU)
        print(f"Transliterated term: {transliterated_term}")

        # Construct the file path from video_id
        file_path = os.path.join(folder_path, f"transcript_{video_id}.txt")

        # Check if the file exists
        if not os.path.exists(file_path):
            print(f"File not found: {file_path}")
            return

        # Read the transcript from the file
        with open(file_path, 'r', encoding='utf-8') as file:
            transcript = file.readlines()

        # Perform fuzzy matching on the transcript
        base_url = f"https://www.youtube.com/watch?v={video_id}&t="
        matches = []

        for line in transcript:
            try:
                start_time, rest = line.split(" - ", 1)
                duration, text = rest.split(": ", 1)
                score = fuzz.partial_ratio(transliterated_term, text.strip())
                if score >= threshold:  # Filter matches above the threshold
                    hyperlink = base_url + str(int(float(start_time))) + "s"
                    matches.append({
                        'text': text.strip(),
                        'start_time': float(start_time),
                        'duration': float(duration),
                        'hyperlink': hyperlink,
                        'score': score
                    })
            except ValueError:
                continue

        # Sort matches by score in descending order
        matches.sort(key=lambda x: x['score'], reverse=True)

        # Output results
        if matches:
            print(f"Found {len(matches)} match(es) for '{search_term}':")
            for match in matches:
                print(f"Score: {match['score']}%")
                print(f"Dialog: {match['text']}")
                print(f"Hyperlink: {match['hyperlink']}\n")
        else:
            print(f"No matches found for '{search_term}'.")

    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    from google.colab import drive
    drive.mount('/content/drive')  # Mount Google Drive

    video_id = 'boHg6quSZtI'  # Replace with your YouTube video ID
    folder_path = '/content/drive/My Drive/YT'  # Google Drive folder path
    search_term = input("Enter the dialog or part of speech to search: ").strip()
    search_transcript_with_fuzzy_matching_from_file(video_id, search_term, folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter the dialog or part of speech to search: anna dandam
# Transliterated term: అన్న దన్దమ్
# Found 3 match(es) for 'anna dandam':
# Score: 76.19047619047619%
# Dialog: అన్న చేత పెట్టించుకుంటాడు మా అన్న పెద్ద
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=429s
#
# Score: 72.72727272727273%
# Dialog: చెప్పేసి రేవంత్ రెడ్డి అన్నాడు దమ్ము
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=653s
#
# Score: 70.58823529411764%
# Dialog: అన్న మెగా స్టార్ మా అన్న అన్నావు మా
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=391s

# %% [markdown]
# V2 - Semantic Search with AI Models
#
# Use senteance transformers to understand the context and return the output

# %%
# !pip install sentence-transformers
# !pip install torch
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.27.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import torch  # Ensure PyTorch is imported
from sentence_transformers import SentenceTransformer, util
import os

def search_transcript_with_semantic_search(video_id, search_term, folder_path, top_k=5):
    try:
        # Load the pre-trained SentenceTransformer model
        model = SentenceTransformer('all-mpnet-base-v2')  # You can choose another model if needed

        # Construct the file path from video_id
        file_path = os.path.join(folder_path, f"transcript_{video_id}.txt")

        # Check if the file exists
        if not os.path.exists(file_path):
            print(f"File not found: {file_path}")
            return

        # Read the transcript from the file
        with open(file_path, 'r', encoding='utf-8') as file:
            transcript_lines = file.readlines()

        # Extract text and timestamps from the transcript
        transcript = []
        start_times = []
        for line in transcript_lines:
            try:
                start_time, rest = line.split(" - ", 1)
                _, text = rest.split(": ", 1)
                transcript.append(text.strip())
                start_times.append(float(start_time))
            except ValueError:
                continue

        # Compute embeddings for the transcript and search query
        transcript_embeddings = model.encode(transcript, convert_to_tensor=True)
        query_embedding = model.encode(search_term, convert_to_tensor=True)

        # Calculate semantic similarity
        similarities = util.pytorch_cos_sim(query_embedding, transcript_embeddings)[0]

        # Retrieve the top-k most similar dialogs
        top_results = torch.topk(similarities, k=top_k)

        print(f"Found {len(top_results.indices)} match(es) for '{search_term}':")
        base_url = f"https://www.youtube.com/watch?v={video_id}&t="
        for idx, score in zip(top_results.indices, top_results.values):
            idx = idx.item()  # Convert tensor to int
            print(f"Score: {score:.2f}")
            print(f"Dialog: {transcript[idx]}")
            print(f"Hyperlink: {base_url}{int(start_times[idx])}s\n")

    except Exception as e:
        print(f"An error occurred: {e.__class__.__name__} - {str(e)}")

# Example usage
if __name__ == "__main__":
    from google.colab import drive
    drive.mount('/content/drive')  # Mount Google Drive

    video_id = 'boHg6quSZtI'  # Replace with your YouTube video ID
    folder_path = '/content/drive/My Drive/YT'  # Google Drive folder path
    search_term = input("Enter the dialog or part of speech to search: ").strip()
    search_transcript_with_semantic_search(video_id, search_term, folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter the dialog or part of speech to search: chandra babu naidu arrest
# Found 5 match(es) for 'chandra babu naidu arrest':
# Score: 0.19
# Dialog: దుర్గం చెరువు ఫ్లై ఓవరా ఆడ బైక్ లో పోతూ
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=561s
#
# Score: 0.19
# Dialog: విల్ బి బిజీ ఇన్ అవర్ లైఫ్ ఇప్పుడు పుష్ప
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=169s
#
# Score: 0.19
# Dialog: నో వాట్ ఎవర్ ద ప్రోగ్రాం నేమ్ బట్ ఐ
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=111s
#
# Score: 0.19
# Dialog: బి బిజీ ఇన్ లైఫ్ లైక్ యు నో మనకు
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=187s
#
# Score: 0.19
# Dialog: ఫార్మింగ్ లేదు ఏం లేదు సీ ఎవరీ వన్ విల్
# Hyperlink: https://www.youtube.com/watch?v=boHg6quSZtI&t=185s

# %% [markdown]
# V2 - SEARCH TRANSCRIPT WITH OPENAI

# %%
# !pip install --upgrade openai tiktoken

from openai import OpenAI
import os
from typing import Optional, List
from google.colab import userdata
import tiktoken

class TeluguTranscriptSearcher:
    def __init__(self):
        """Initialize the TranscriptSearcher with OpenAI API credentials from Colab secrets."""
        api_key = userdata.get('OPENAI_API_KEY')
        if not api_key:
            raise ValueError("OPENAI_API_KEY not found in Colab secrets")

        self.client = OpenAI(api_key=api_key)
        self.encoding = tiktoken.encoding_for_model("gpt-4")
        self.max_tokens = 6000

    @staticmethod
    def format_youtube_link(video_id: str, timestamp_seconds: int) -> str:
        """Generate a YouTube link with timestamp."""
        return f"https://youtube.com/watch?v={video_id}&t={timestamp_seconds}s"

    def count_tokens(self, text: str) -> int:
        """Count the number of tokens in a text string."""
        return len(self.encoding.encode(text))

    def chunk_transcript(self, transcript: str) -> List[str]:
        """Split transcript into chunks that fit within token limit."""
        chunks = []
        lines = transcript.split('\n')
        current_chunk = []
        current_tokens = 0

        for line in lines:
            line_tokens = self.count_tokens(line)

            if current_tokens + line_tokens > self.max_tokens:
                if current_chunk:
                    chunks.append('\n'.join(current_chunk))
                current_chunk = [line]
                current_tokens = line_tokens
            else:
                current_chunk.append(line)
                current_tokens += line_tokens

        if current_chunk:
            chunks.append('\n'.join(current_chunk))

        return chunks

    def read_transcript(self, file_path: str) -> Optional[str]:
        """Read transcript from a file."""
        if not os.path.exists(file_path):
            print(f"File not found: {file_path}")
            return None

        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                return file.read()
        except IOError as e:
            print(f"Error reading file: {str(e)}")
            return None

    def search_chunk(self, chunk: str, search_term: str, video_id: str, max_tokens: int = 1000) -> Optional[str]:
        """Search a single chunk of Telugu transcript."""
        try:
            messages = [
                {"role": "system", "content": """You are a bilingual assistant expert in Telugu and English.
Your task is to find relevant content in Telugu transcripts based on English queries.
When you find matches, provide the original Telugu text, its English translation, and a YouTube link with timestamp."""},
                {"role": "user", "content": f"""
The following is part of a Telugu video transcript. Find dialogs or parts most relevant to the English query.
Only return matches if they are highly relevant. If no relevant matches are found, return empty string.

Transcript (Telugu):
{chunk}

Query (English):
{search_term}

For each match, return in this format:
[Timestamp in seconds]
Telugu: (original Telugu text)
English: (English translation)
Link: {self.format_youtube_link(video_id, "TIMESTAMP")} (replace TIMESTAMP with the actual seconds)

Note: Always include the timestamp in seconds and generate the full YouTube link.
"""}
            ]

            response = self.client.chat.completions.create(
                model="gpt-4",
                messages=messages,
                max_tokens=max_tokens,
                temperature=0.7
            )

            return response.choices[0].message.content.strip()

        except Exception as e:
            print(f"Error processing chunk: {str(e)}")
            return None

    def search_transcript(self,
                         video_id: str,
                         search_term: str,
                         folder_path: str) -> Optional[str]:
        """Search through a Telugu video transcript for relevant content."""
        try:
            # Read and chunk the transcript
            file_path = os.path.join(folder_path, f"transcript_{video_id}.txt")
            full_transcript = self.read_transcript(file_path)

            if not full_transcript:
                return None

            chunks = self.chunk_transcript(full_transcript)
            print(f"Split transcript into {len(chunks)} chunks")

            # Search each chunk
            all_results = []
            for i, chunk in enumerate(chunks, 1):
                print(f"Processing chunk {i}/{len(chunks)}...")
                result = self.search_chunk(chunk, search_term, video_id)
                if result and result.strip():
                    all_results.append(result)

            # Combine and format results
            if not all_results:
                return "No relevant dialogs found. Note: The search was performed on Telugu content using your English query."

            return "\n\n".join(all_results)

        except Exception as e:
            print(f"An error occurred: {e.__class__.__name__} - {str(e)}")
            return None

def main():
    """Main function to run the transcript search"""
    try:
        # Mount Google Drive
        from google.colab import drive
        drive.mount('/content/drive')

        # Initialize the searcher
        searcher = TeluguTranscriptSearcher()

        # Set up search parameters
        video_id = 'boHg6quSZtI'  # Replace with your YouTube video ID
        folder_path = '/content/drive/My Drive/YT'
        search_term = input("Enter your search term in English: ").strip()

        print("\nSearching Telugu transcript for relevant content...")
        # Perform search
        result = searcher.search_transcript(video_id, search_term, folder_path)

        # Print results
        if result:
            print("\nSearch Results:")
            print("-" * 50)
            print(result)

    except Exception as e:
        print(f"An error occurred in main: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.59.3)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter your search term in English: what presenter agree with revanth reddy
#
# Searching Telugu transcript for relevant content...
# Split transcript into 4 chunks
# Processing chunk 1/4...
# Processing chunk 2/4...
# Processing chunk 3/4...
# Processing chunk 4/4...
#
# Search Results:
# --------------------------------------------------
# No relevant matches found in the provided Telugu transcript for the English query.
#
# 259.519 - 5.281: రేవంత్ రెడ్డి అన్న మాటలతో నేను కొంతవరకు
# 262.72 - 5.84: ఏకీభవిస్తాను కొంతవరకు నేను విభేదిస్తాను
#
# [Timestamp in seconds: 259.519 - 265.56]
# Telugu: (రేవంత్ రెడ్డి అన్న మాటలతో నేను కొంతవరకు ఏకీభవిస్తాను కొంతవరకు నేను విభేదిస్తాను)
# English: (I agree to some extent with what Revanth Reddy said, and I disagree to some extent)
# Link: https://youtube.com/watch?v=boHg6quSZtI&t=259s
#
# No relevant matches found in the provided Telugu transcript for the English query.
#
# Apologies, but the provided Telugu transcript does not contain any content that is highly relevant to the English query about what the presenter agrees with Revanth Reddy.

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
